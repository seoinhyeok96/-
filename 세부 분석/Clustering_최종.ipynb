# %% [markdown]
# 집단별 어떤 브랜드, 카테고리 제품의 푸시 알림을 보내는게 좋을까?

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("darkgrid")
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
# "rfm.csv" 읽고 CustomerID 인덱스로 지정하기
df = pd.read_parquet('rfm_total.parquet.gzip')
df.shape
# Out:
# (228393, 9)

# %%
# Recency, Frequency, MonetaryValue 만 따로 rfm_cluster 변수에 담아 사용하기
rfm_cluster = df[['Recency', 'Frequency', 'MonetaryValue']]
print(rfm_cluster.shape)
rfm_cluster
# Out:
# (228393, 3)
#            Recency  Frequency  MonetaryValue
# user_id
# 384989212       14          1      41.439999
# 401021311       11          1     231.639999
# 403013066       14          2     807.160034
# 410333972        1          1     591.250000
# 415873351        1          2     263.059998
# ...            ...        ...            ...
# 566265448        1          1     592.010010
# 566267483        1          2      30.740000
# 566270060        1          2     147.419998
# 566274637        1          1    2011.630005
# 566278294        1          1    1661.089966
#
# [228393 rows x 3 columns]

# %%
rfm_cluster.describe()
# Out:
#              Recency      Frequency  MonetaryValue
# count  228393.000000  228393.000000  228393.000000
# mean       14.339691       1.986742     737.289917
# std         9.384898       3.243977    2003.170410
# min         1.000000       1.000000       0.880000
# 25%         6.000000       1.000000     143.119995
# 50%        12.000000       1.000000     285.720001
# 75%        24.000000       2.000000     730.260010
# max        31.000000     291.000000  198916.640625

# %%
sns.countplot(data=df, x="Recency")
# Out:
# <Axes: xlabel='Recency', ylabel='count'>

# %%
rfm_cluster.hist(bins=50);

# %%
# log 변환
# 회귀나 k-means에서 log 변환 시 성능이 조금 더 좋아짐

rfm_cluster_log = np.log(rfm_cluster + 1)
rfm_cluster_log.head()
# Out:
#             Recency  Frequency  MonetaryValue
# user_id
# 384989212  2.708050   0.693147       3.748091
# 401021311  2.484907   0.693147       5.449492
# 403013066  2.708050   1.098612       6.694760
# 410333972  0.693147   0.693147       6.383929
# 415873351  0.693147   1.098612       5.576176

# %%
rfm_cluster_log.hist(bins=50);

# %%
rfm_cluster_log.describe()
# Out:
#              Recency      Frequency  MonetaryValue
# count  228393.000000  228393.000000  228393.000000
# mean        2.482504       0.944337       5.765843
# std         0.774222       0.441100       1.240259
# min         0.693147       0.693147       0.631272
# 25%         1.945910       0.693147       4.970646
# 50%         2.564949       0.693147       5.658506
# 75%         3.218876       1.098612       6.594769
# max         3.465736       5.676754      12.200646

# %% [markdown]
# ## 스케일링

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

scaler = StandardScaler()
X = scaler.fit_transform(rfm_cluster_log)
X
# Out:
# array([[ 0.29132083, -0.56946415, -1.62675977],
#        [ 0.00310372, -0.56946415, -0.2550502 ],
#        [ 0.29132083,  0.34975059,  0.74891462],
#        ...,
#        [-2.31117221,  0.34975059, -0.61740398],
#        [-2.31117221, -0.56946415,  1.48454329],
#        [-2.31117221, -0.56946415,  1.33025895]])

# %%
# 데이터 프레임으로 저장
pd.DataFrame(X).describe().round(2)
# Out:
#                0          1          2
# count  228393.00  228393.00  228393.00
# mean       -0.00      -0.00      -0.00
# std         1.00       1.00       1.00
# min        -2.31      -0.57      -4.14
# 25%        -0.69      -0.57      -0.64
# 50%         0.11      -0.57      -0.09
# 75%         0.95       0.35       0.67
# max         1.27      10.73       5.19

# %% [markdown]
# ## KMeans

# %%
from sklearn.cluster import KMeans
from tqdm import tqdm
from sklearn.metrics import silhouette_score
import warnings
warnings.filterwarnings('ignore')

inertia = [] # 같은 애들끼리 얼마나 똘똘 뭉쳐있는지
silhouettes = []
range_n_clusters = range(2, 10)

for n_cluster in tqdm(range(2, 10)):
    kmeans = KMeans(n_clusters=n_cluster, random_state=42)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)
    silhouettes.append(silhouette_score(X, labels=kmeans.labels_))
    print(n_cluster, end=',')

# %% [markdown]
# ## Elbow Method

# %%
plt.figure(figsize=(15,4))
plt.plot(range_n_clusters, inertia)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Within-Cluster Sum of Square')
plt.xticks(range_n_clusters)
plt.show()

# %% [markdown]
# ## Silhouette Score

# %%
plt.figure(figsize=(15, 4))
plt.title('Silhouette Score')
plt.plot(range_n_clusters, silhouettes)
plt.xticks(range_n_clusters)
plt.show()

# %% [markdown]
# ## KElbowVisualizer

# %%
# yellowbrick.cluster 에서 KElbowVisualizer 불러오기
from yellowbrick.cluster import KElbowVisualizer

KEV = KElbowVisualizer(kmeans, k=10, n_init="auto")
KEV.fit(X)
KEV.show()

# %% [markdown]
# ## 분석한 내용을 바탕으로 KMeans n_clusters 값을 정해 학습하기

# %%
n_clusters = 4
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
kmeans.labels_
# Out:
# array([1, 1, 3, ..., 0, 0, 0])

# %%
pd.Series(kmeans.labels_).value_counts()
# Out:
# 1    82882
# 3    66557
# 0    55713
# 2    23241
# dtype: int64

# %%
# silhouette_score 구하기
silhouette_avg = silhouette_score(X, kmeans.labels_)
silhouette_avg

# %%
# https://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html
from sklearn.metrics import silhouette_samples
import matplotlib.cm as cm

# Create a subplot with 1 row and 2 columns
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_size_inches(18, 7)

# The 1st subplot is the silhouette plot
# The silhouette coefficient can range from -1, 1 but in this example all
# lie within [-0.1, 1]
ax1.set_xlim([-0.1, 1])
# The (n_clusters+1)*10 is for inserting blank space between silhouette
# plots of individual clusters, to demarcate them clearly.
ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])
    
cluster_labels = kmeans.labels_
sample_silhouette_values = silhouette_samples(X, cluster_labels)

y_lower = 10
for i in range(n_clusters):
    # Aggregate the silhouette scores for samples belonging to
    # cluster i, and sort them
    ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

    ith_cluster_silhouette_values.sort()

    size_cluster_i = ith_cluster_silhouette_values.shape[0]
    y_upper = y_lower + size_cluster_i

    color = cm.nipy_spectral(float(i) / n_clusters)
    ax1.fill_betweenx(
        np.arange(y_lower, y_upper),
        0,
        ith_cluster_silhouette_values,
        facecolor=color,
        edgecolor=color,
        alpha=0.7,
    )

    # Label the silhouette plots with their cluster numbers at the middle
    ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

    # Compute the new y_lower for next plot
    y_lower = y_upper + 10  # 10 for the 0 samples

ax1.set_title("The silhouette plot for the various clusters.")
ax1.set_xlabel("The silhouette coefficient values")
ax1.set_ylabel("Cluster label")

# The vertical line for average silhouette score of all the values
ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

ax1.set_yticks([])  # Clear the yaxis labels / ticks
ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

# 2nd Plot showing the actual clusters formed
colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
ax2.scatter(
    X[:, 0], X[:, 1], marker=".", s=30, lw=0, alpha=0.7, c=colors, edgecolor="k"
)

# Labeling the clusters
centers = kmeans.cluster_centers_
# Draw white circles at cluster centers
ax2.scatter(
    centers[:, 0],
    centers[:, 1],
    marker="o",
    c="white",
    alpha=1,
    s=200,
    edgecolor="k",
)

for i, c in enumerate(centers):
    ax2.scatter(c[0], c[1], marker="$%d$" % i, alpha=1, s=50, edgecolor="k")

ax2.set_title("The visualization of the clustered data.")
ax2.set_xlabel("Feature space for the 1st feature")
ax2.set_ylabel("Feature space for the 2nd feature")

plt.suptitle(
    "Silhouette analysis for KMeans clustering on sample data with n_clusters = %d"
    % n_clusters,
    fontsize=14,
    fontweight="bold",
)

plt.show()

# %%
df['Cluster'] = kmeans.labels_
df.head()
# Out:
#            Recency  Frequency  MonetaryValue  R  F  M RFM_segment  RFM_score  \
# user_id
# 384989212       14          1      41.439999  3  1  1         311          5
# 401021311       11          1     231.639999  3  1  3         313          7
# 403013066       14          2     807.160034  3  4  4         344         11
# 410333972        1          1     591.250000  5  1  4         514         10
# 415873351        1          2     263.059998  5  4  3         543         12
#
#           RFM_class  Cluster
# user_id
# 384989212    silver        1
# 401021311    silver        1
# 403013066  platinum        3
# 410333972      gold        0
# 415873351  platinum        0

# %%
df_reset = df.reset_index()
df_reset
# Out:
#           user_id  Recency  Frequency  MonetaryValue  R  F  M RFM_segment  \
# 0       384989212       14          1      41.439999  3  1  1         311
# 1       401021311       11          1     231.639999  3  1  3         313
# 2       403013066       14          2     807.160034  3  4  4         344
# 3       410333972        1          1     591.250000  5  1  4         514
# 4       415873351        1          2     263.059998  5  4  3         543
# ...           ...      ...        ...            ... .. .. ..         ...
# 228388  566265448        1          1     592.010010  5  4  4         544
# 228389  566267483        1          2      30.740000  5  5  1         551
# 228390  566270060        1          2     147.419998  5  5  2         552
# 228391  566274637        1          1    2011.630005  5  4  5         545
# 228392  566278294        1          1    1661.089966  5  4  5         545
#
#         RFM_score RFM_class  Cluster
# 0               5    silver        1
# 1               7    silver        1
# 2              11  platinum        3
# 3              10      gold        0
# 4              12  platinum        0
# ...           ...       ...      ...
# 228388         13  platinum        0
# 228389         11  platinum        0
# 228390         12  platinum        0
# 228391         14  platinum        0
# 228392         14  platinum        0
#
# [228393 rows x 11 columns]

# %%
# class를 qcut으로 구한거랑 머신러닝으로 구한 것 비교
pd.crosstab(df['RFM_class'], df['Cluster'])
# Out:
# Cluster        0      1      2      3
# RFM_class
# silver      4702  66581      2   9011
# gold       25345  16292    105  33774
# platinum   25666      9  23134  23772

# %%
rfm_cluster_log
# Out:
#             Recency  Frequency  MonetaryValue
# user_id
# 384989212  2.708050   0.693147       3.748091
# 401021311  2.484907   0.693147       5.449492
# 403013066  2.708050   1.098612       6.694760
# 410333972  0.693147   0.693147       6.383929
# 415873351  0.693147   1.098612       5.576176
# ...             ...        ...            ...
# 566265448  0.693147   0.693147       6.385211
# 566267483  0.693147   1.098612       3.457578
# 566270060  0.693147   1.098612       5.000046
# 566274637  0.693147   0.693147       7.607198
# 566278294  0.693147   0.693147       7.415831
#
# [228393 rows x 3 columns]

# %%
scaler = StandardScaler()
rfm_cluster_log[['Recency','Frequency','MonetaryValue']] = scaler.fit_transform(rfm_cluster_log[['Recency','Frequency','MonetaryValue']])
rfm_cluster_log.head()
# Out:
#             Recency  Frequency  MonetaryValue
# user_id
# 384989212  0.291321  -0.569464      -1.626760
# 401021311  0.003104  -0.569464      -0.255050
# 403013066  0.291321   0.349751       0.748915
# 410333972 -2.311172  -0.569464       0.498315
# 415873351 -2.311172   0.349751      -0.152914

# %% [markdown]
# ### 보기만 많이 한 제품

# %%
# 전체 데이터프레임 total에 저장
total = pd.read_parquet('df_total.parquet.gzip')
total.head()
# Out:
#                  event_time event_type  product_id            category_code  \
# 0 2019-10-16 12:04:37+00:00       view     7900918  furniture.kitchen.chair
# 1 2019-10-16 12:04:37+00:00       view     1003317   electronics.smartphone
# 2 2019-10-16 12:04:37+00:00       view     2501929  appliances.kitchen.oven
# 3 2019-10-16 12:04:37+00:00       view     1004833   electronics.smartphone
# 4 2019-10-16 12:04:37+00:00       cart     1004836   electronics.smartphone
#
#      brand       price    user_id
# 0     joie  102.709999  560842110
# 1    apple  952.150024  560842739
# 2     asel   61.750000  525817175
# 3  samsung  172.169998  515456548
# 4  samsung  229.410004  529758564

# %%
total.shape
# Out:
# (22146517, 7)

# %%
# event_type이 view
df_view = total[total['event_type'] == 'view']
df_view
# Out:
#                        event_time event_type  product_id  \
# 0       2019-10-16 12:04:37+00:00       view     7900918
# 1       2019-10-16 12:04:37+00:00       view     1003317
# 2       2019-10-16 12:04:37+00:00       view     2501929
# 3       2019-10-16 12:04:37+00:00       view     1004833
# 6       2019-10-16 12:04:37+00:00       view     1500447
# ...                           ...        ...         ...
# 7074788 2019-10-11 17:54:47+00:00       view     3601261
# 7074789 2019-10-11 17:54:47+00:00       view     2800660
# 7074791 2019-10-11 17:54:47+00:00       view     4900396
# 7074792 2019-10-11 17:54:47+00:00       view     1801350
# 7074793 2019-10-11 17:54:47+00:00       view    21400931
#
#                             category_code     brand       price    user_id
# 0                 furniture.kitchen.chair      joie  102.709999  560842110
# 1                  electronics.smartphone     apple  952.150024  560842739
# 2                 appliances.kitchen.oven      asel   61.750000  525817175
# 3                  electronics.smartphone   samsung  172.169998  515456548
# 6           computers.peripherals.printer        hp  136.169998  544343611
# ...                                   ...       ...         ...        ...
# 7074788         appliances.kitchen.washer     bosch  476.119995  515598105
# 7074789  appliances.kitchen.refrigerators  dauscher  156.220001  557716137
# 7074791         appliances.kitchen.juicer     bosch  101.389999  522609644
# 7074792              electronics.video.tv   toshiba  437.510010  505550850
# 7074793                electronics.clocks     casio   51.200001  513460824
#
# [21049387 rows x 7 columns]

# %%
# 제일 많이 view된 제품 id를 찾음
df_view.groupby(['product_id'])[['user_id']].count().sort_values(by='user_id', ascending=False)
# Out:
#             user_id
# product_id
# 1004856      352660
# 1004767      319501
# 1005115      274762
# 1004249      172483
# 1004833      168744
# ...             ...
# 13900992          1
# 13900990          1
# 35108728          1
# 35108723          1
# 21408327          1
#
# [59626 rows x 1 columns]

# %%
# 사람들이 가장 많이 본(view) 상위 5개의 product_id 구하기
# 결과: 1004856, 1004767, 1005115, 1004249, 1004833번 product
idx = df_view.groupby(['product_id'])[['user_id']].count().sort_values(by='user_id', ascending=False).head(5).index
idx
# Out:
# Int64Index([1004856, 1004767, 1005115, 1004249, 1004833], dtype='int64', name='product_id')

# %%
idx = idx.to_list() # 리스트로 변환

# %%
view_max = df_view[df_view['product_id'].isin(idx)][['category_code', 'brand', 'user_id','product_id']]
view_max # 위 결과에서 나온 product_id의 일부 컬럼만 출력
# Out:
#                   category_code    brand    user_id  product_id
# 3        electronics.smartphone  samsung  515456548     1004833
# 14       electronics.smartphone  samsung  534900903     1004856
# 18       electronics.smartphone  samsung  513747311     1004856
# 49       electronics.smartphone  samsung  560838312     1004856
# 94       electronics.smartphone  samsung  514791097     1004856
# ...                         ...      ...        ...         ...
# 7074661  electronics.smartphone  samsung  542522794     1004856
# 7074702  electronics.smartphone  samsung  518985190     1004767
# 7074704  electronics.smartphone  samsung  516643465     1004833
# 7074706  electronics.smartphone  samsung  559253574     1004856
# 7074740  electronics.smartphone  samsung  520769832     1004767
#
# [1288150 rows x 4 columns]

# %%
view_max['category_code'].value_counts(1).plot.bar(rot=0)
# electronics.smartphone이 거의 90퍼센트
# Out:
# <Axes: >

# %%
view_max['brand'].value_counts(1).plot.bar(rot=0) 
# smartphone 브랜드 samsumg, apple 순으로 높음
# Out:
# <Axes: >

# %% [markdown]
# ### 많이 본 제품 top5에 해당하는 user들이 구매는 안 했을까?

# %%
view_max.head()
# Out:
#              category_code    brand    user_id  product_id
# 3   electronics.smartphone  samsung  515456548     1004833
# 14  electronics.smartphone  samsung  534900903     1004856
# 18  electronics.smartphone  samsung  513747311     1004856
# 49  electronics.smartphone  samsung  560838312     1004856
# 94  electronics.smartphone  samsung  514791097     1004856

# %%
# view_max는 view의 top5에 해당하는 제품들
# view의 top5에 해당하는 제품들을 본 총 사람 수
view_max['user_id'].nunique()
# Out:
# 480327

# %%
# 리스트로 변환
user = view_max['user_id'].to_list()
user
# Out:
# [515456548,
#  534900903,
#  513747311,
#  560838312,
#  514791097,
#  545947702,
#  560836294,
#  515427976,
#  534900903,
#  560152136,
#  551218977,
#  557518153,
#  560838312,
#  550710063,
#  558439246,
#  556539700,
#  516097231,
#  544928566,
#  514128238,
#  560836294,
#  560843218,
#  545113097,
#  513747311,
#  560842045,
#  554416727,
#  560842641,
#  548492495,
#  560843235,
#  523821076,
#  555641911,
#  553024182,
#  529721826,
#  529278312,
#  513095488,
#  527301264,
#  516306205,
#  533813761,
#  512568434,
#  554055237,
#  517144035,
#  523821076,
#  515043509,
#  517222549,
#  560842150,
#  517613262,
#  514317823,
#  522039617,
#  559176293,
#  520938537,
#  548518784,
#  543566334,
#  533813761,
#  515427976,
#  557295955,
#  543566334,
#  536070513,
#  516673286,
#  553024182,
#  517719100,
#  513095488,
#  544928566,
#  514751967,
#  512515727,
#  560843803,
#  533813761,
#  512698088,
#  543566334,
#  560843210,
#  516898920,
#  546986785,
#  560841779,
#  512923243,
#  559176293,
#  512699835,
#  515999249,
#  513077951,
#  516048316,
#  544821712,
#  560843235,
#  513395079,
#  549684152,
#  512698088,
#  560841784,
#  560441021,
#  520938537,
#  560441021,
#  560843707,
#  539996891,
#  517590507,
#  555540935,
#  560410186,
#  559176293,
#  515999249,
#  544928566,
#  518780552,
#  514656403,
#  559176293,
#  527301264,
#  560843868,
#  542097553,
#  512698088,
#  514461364,
#  524320796,
#  560841886,
#  560499559,
#  556640054,
#  558414466,
#  540414279,
#  560843235,
#  546227216,
#  513432600,
#  555484299,
#  551763176,
#  560844035,
#  529333488,
#  527868705,
#  553024182,
#  512698088,
#  558414466,
#  540135730,
#  536439641,
#  557443320,
#  513100155,
#  554055237,
#  513747311,
#  512923243,
#  560844053,
#  540037209,
#  526914855,
#  556386832,
#  545560017,
#  554845968,
#  521397353,
#  559476470,
#  560844223,
#  560843210,
#  560842641,
#  546986785,
#  560045476,
#  512521011,
#  512419524,
#  560843868,
#  560844035,
#  560842641,
#  528283014,
#  512373029,
#  540037209,
#  514751967,
#  512373029,
#  560843970,
#  512698088,
#  513395079,
#  513432600,
#  555638508,
#  517000868,
#  512923243,
#  527334415,
#  554416727,
#  557699472,
#  559404447,
#  560842119,
#  560844554,
#  513395079,
#  553024182,
#  513077951,
#  525057378,
#  514461364,
#  512865691,
#  551623503,
#  557699472,
#  560843868,
#  525608960,
#  514461364,
#  519394477,
#  536600740,
#  524441454,
#  526914855,
#  536016675,
#  546373629,
#  512419524,
#  512419524,
#  513077951,
#  533813761,
#  513747311,
#  527237302,
#  560844554,
#  525608960,
#  535097033,
#  560843210,
#  516462363,
#  512698088,
#  516524487,
#  560837661,
#  523097136,
#  525608960,
#  560606761,
#  560844315,
#  560712372,
#  533813761,
#  545560017,
#  513447288,
#  516704623,
#  560844514,
#  516462363,
#  560189072,
#  560842739,
#  528283014,
#  525608960,
#  555667048,
#  560843803,
#  560501516,
#  524320796,
#  560840944,
#  554044159,
#  546986785,
#  560841959,
#  524441454,
#  516048316,
#  546846441,
#  560844967,
#  512865691,
#  560836294,
#  518107481,
#  513560925,
#  515082682,
#  528373101,
#  514900330,
#  532343400,
#  560845017,
#  517302165,
#  512373029,
#  512865691,
#  546986785,
#  512881225,
#  560844977,
#  551971075,
#  524370224,
#  560844223,
#  536016675,
#  513560925,
#  539401681,
#  555667048,
#  560844554,
#  560844223,
#  560843897,
#  551430090,
#  560845079,
#  560538205,
#  528283014,
#  531528384,
#  524095778,
#  560843616,
#  517302165,
#  512881225,
#  521078516,
#  552386415,
#  549515937,
#  514232447,
#  559683200,
#  512938696,
#  512373029,
#  513538297,
#  521397353,
#  539605015,
#  528373101,
#  514457474,
#  513687382,
#  524320796,
#  551430090,
#  532367375,
#  560844969,
#  524370224,
#  516704623,
#  542998815,
#  553825721,
#  552059033,
#  522547143,
#  555149877,
#  512698088,
#  533094928,
#  521078516,
#  540232936,
#  560843605,
#  554044159,
#  540835840,
#  514556303,
#  535527451,
#  513009991,
#  512938696,
#  557918275,
#  514691607,
#  523156122,
#  556920707,
#  516757604,
#  514816607,
#  514656403,
#  560845325,
#  553974309,
#  517923866,
#  514457474,
#  523156122,
#  558420737,
#  521078516,
#  560845210,
#  560501516,
#  517335524,
#  514691607,
#  547533760,
#  512895446,
#  528245056,
#  515669945,
#  554760123,
#  521599109,
#  514902642,
#  538509773,
#  513201649,
#  528359323,
#  547463751,
#  518107481,
#  515999249,
#  560441309,
#  544280161,
#  514900330,
#  559324897,
#  560845605,
#  546775141,
#  537141537,
#  559911460,
#  525608960,
#  559019325,
#  514902642,
#  525608960,
#  537722952,
#  517335524,
#  528245056,
#  560843897,
#  517923866,
#  515075391,
#  560845210,
#  559019325,
#  541310498,
#  543191801,
#  560778471,
#  513447288,
#  537141537,
#  523331538,
#  513201649,
#  513009991,
#  519705747,
#  519136514,
#  530219379,
#  512965848,
#  513939687,
#  485280944,
#  530873584,
#  532085367,
#  525994560,
#  517923866,
#  541310498,
#  551158498,
#  512890415,
#  516704623,
#  515075391,
#  513939687,
#  540370616,
#  560842581,
#  556663534,
#  516607315,
#  560845210,
#  554271473,
#  560778471,
#  526121840,
#  555149877,
#  525994560,
#  517875753,
#  516704623,
#  523189324,
#  547267723,
#  521430824,
#  556663534,
#  560687881,
#  559421629,
#  560845508,
#  513306169,
#  535781221,
#  512725368,
#  516535482,
#  550831831,
#  560845421,
#  560501516,
#  513371924,
#  519136514,
#  520359588,
#  557918275,
#  560845892,
#  514743759,
#  546361685,
#  550831831,
#  555149877,
#  557699472,
#  516704623,
#  560845210,
#  560441021,
#  513371924,
#  516119953,
#  557918275,
#  560843210,
#  560690625,
#  536383145,
#  536842327,
#  523156122,
#  515075391,
#  512890415,
#  559421629,
#  552872228,
#  560845384,
#  514902642,
#  560845892,
#  522547143,
#  546077374,
#  523331538,
#  553825721,
#  513371924,
#  525994560,
#  560786127,
#  514457474,
#  560843235,
#  558040108,
#  556663534,
#  516679152,
#  560846164,
#  520166177,
#  544645777,
#  552786016,
#  518405803,
#  512850629,
#  560845582,
#  543191801,
#  552499722,
#  521210776,
#  560845210,
#  553825721,
#  512955992,
#  544645777,
#  513371924,
#  560843361,
#  549437637,
#  520166177,
#  512890415,
#  553825721,
#  559717880,
#  530873584,
#  512402596,
#  519917561,
#  559421629,
#  530873584,
#  530873584,
#  514979628,
#  512850629,
#  512955992,
#  560845801,
#  534843836,
#  560786127,
#  560839314,
#  547267723,
#  543103791,
#  559402291,
#  546933639,
#  519497399,
#  560259609,
#  557918275,
#  519614274,
#  551069854,
#  556664572,
#  513657148,
#  535781221,
#  548622920,
#  551321134,
#  512890415,
#  560843361,
#  552499722,
#  512419524,
#  512725368,
#  519244531,
#  560845776,
#  516623010,
#  558987804,
#  512736473,
#  557152635,
#  514614781,
#  553404723,
#  547429800,
#  545349142,
#  546933639,
#  550225952,
#  516679152,
#  560845508,
#  513488869,
#  560846830,
#  516778090,
#  543289544,
#  557152635,
#  536024376,
#  560810379,
#  519917561,
#  538547264,
#  517026501,
#  512852209,
#  529796907,
#  560845955,
#  479040697,
#  519917561,
#  558040108,
#  520166177,
#  560778471,
#  555484299,
#  549169760,
#  560845955,
#  536024376,
#  538591087,
#  560846535,
#  517026501,
#  558987804,
#  555484299,
#  519705747,
#  544049103,
#  523586838,
#  536024376,
#  560846924,
#  518897200,
#  540304035,
#  520359588,
#  547267723,
#  519182044,
#  555634210,
#  543662993,
#  516847454,
#  549437637,
#  521465569,
#  538969702,
#  552671796,
#  525146522,
#  521207499,
#  558040108,
#  560846977,
#  516617888,
#  555758112,
#  558040108,
#  512890415,
#  535781221,
#  515402897,
#  518514083,
#  560847246,
#  530894741,
#  558493614,
#  553559677,
#  535573036,
#  557957850,
#  560441021,
#  542524481,
#  516058068,
#  553559677,
#  553156718,
#  536987321,
#  556419654,
#  554887779,
#  514513464,
#  560847306,
#  560441021,
#  538969702,
#  557023082,
#  558493614,
#  560846924,
#  525566375,
#  549281192,
#  560847552,
#  518597811,
#  519136514,
#  544750637,
#  560847552,
#  519236048,
#  541822903,
#  518383879,
#  514972446,
#  538509773,
#  556822190,
#  512890415,
#  545994621,
#  544821712,
#  519229942,
#  560847306,
#  554887779,
#  551158498,
#  543191801,
#  514972446,
#  512396845,
#  540304035,
#  550200726,
#  516850181,
#  537076709,
#  557519137,
#  513057964,
#  540635338,
#  560834890,
#  531926658,
#  560847659,
#  520765035,
#  516024274,
#  560847265,
#  560845955,
#  560845582,
#  518620607,
#  523383438,
#  549169760,
#  523371573,
#  516524487,
#  533505996,
#  560338814,
#  560847904,
#  533720556,
#  540304035,
#  560847499,
#  523742805,
#  560338814,
#  533505996,
#  531235483,
#  540375049,
#  560847516,
#  548528722,
#  529699061,
#  554069907,
#  544821712,
#  555634210,
#  550775752,
#  552133814,
#  520166177,
#  518836316,
#  514193503,
#  560786127,
#  542140087,
#  540377287,
#  560847659,
#  514972446,
#  516524487,
#  560845955,
#  540304035,
#  522613414,
#  512669486,
#  523383438,
#  512410861,
#  560847552,
#  555669573,
#  543191801,
#  550200726,
#  547267723,
#  542706509,
#  536383145,
#  514193503,
#  560834890,
#  550704221,
#  512736473,
#  515602753,
#  560577379,
#  560847659,
#  558034187,
#  555977063,
#  516551650,
#  514972446,
#  554198326,
#  527331984,
#  560845582,
#  553825721,
#  537076709,
#  529699061,
#  560847265,
#  514786101,
#  516049106,
#  523383438,
#  550704221,
#  549691242,
#  534955787,
#  559545593,
#  545675886,
#  557309404,
#  529322962,
#  512410861,
#  560847659,
#  547967032,
#  538509773,
#  526822489,
#  512531017,
#  556297692,
#  543191801,
#  560843210,
#  545675886,
#  515602753,
#  519111595,
#  536383145,
#  541046715,
#  540304035,
#  543662993,
#  560848223,
#  535866709,
#  560848323,
#  513218746,
#  515628249,
#  517574408,
#  551811560,
#  514786101,
#  515043509,
#  522613414,
#  531926658,
#  560847904,
#  560848478,
#  522557542,
#  560847904,
#  560846924,
#  560848478,
#  558025810,
#  522613414,
#  560813888,
#  560848566,
#  560848465,
#  514899552,
#  552261468,
#  512736473,
#  540304035,
#  547967032,
#  534618836,
#  531269474,
#  530564276,
#  560848566,
#  560834428,
#  549227793,
#  541514813,
#  516339207,
#  547536437,
#  514538372,
#  560848478,
#  542290826,
#  512531017,
#  531952670,
#  559545593,
#  524046390,
#  558255002,
#  548132948,
#  560223400,
#  556663534,
#  517000868,
#  521454023,
#  560848465,
#  534618836,
#  519943592,
#  552723900,
#  559545593,
#  545315121,
#  550049373,
#  549227793,
#  528359323,
#  515146450,
#  556951919,
#  531269474,
#  536731908,
#  557262770,
#  529074701,
#  555332580,
#  519509117,
#  534618836,
#  512650761,
#  547835177,
#  529852808,
#  518860125,
#  560848566,
#  543087476,
#  515250169,
#  550049373,
#  560848424,
#  529178533,
#  514538372,
#  556729872,
#  549281192,
#  512650761,
#  558675609,
#  549584746,
#  523383438,
#  552133814,
#  534618836,
#  560848465,
#  536383145,
#  519236048,
#  514490639,
#  560848649,
#  524370224,
#  554387483,
#  560840698,
#  515082682,
#  552261468,
#  552723900,
#  536418795,
#  517000868,
#  518597811,
#  543191801,
#  549227793,
#  542388094,
#  539640804,
#  553985695,
#  519039132,
#  547499517,
#  560846535,
#  555149877,
#  544806601,
#  513683672,
#  537314436,
#  560847265,
#  513218746,
#  548528722,
#  517590205,
#  560849085,
#  516597562,
#  554472659,
#  560848806,
#  554387483,
#  517000868,
#  518860125,
#  560449610,
#  513756055,
#  528456723,
#  515602753,
#  554387483,
#  529699061,
#  536827130,
#  549281192,
#  559978538,
#  549546829,
#  560848988,
#  560843841,
#  545880601,
#  558675609,
#  528187192,
#  560848553,
#  515002897,
#  556663534,
#  531926658,
#  553722279,
#  560845955,
#  549584746,
#  546815256,
#  560840698,
#  560849087,
#  550837035,
#  554527979,
#  549546829,
#  560449610,
#  543191801,
#  556580519,
#  517000868,
#  512419524,
#  556663534,
#  543844644,
#  560847904,
#  557262770,
#  560846977,
#  556479215,
#  514899552,
#  522616505,
#  553693525,
#  527001323,
#  560848982,
#  560845955,
#  514531995,
#  513199335,
#  560848432,
#  528079872,
#  512427243,
#  549437637,
#  513364093,
#  546775141,
#  534652351,
#  558675609,
#  560845955,
#  519638376,
#  521123033,
#  529074701,
#  543191801,
#  560774772,
#  556508845,
#  560546349,
#  515421004,
#  521123033,
#  560843841,
#  560768594,
#  533556767,
#  512410787,
#  520254190,
#  558025810,
#  519638376,
#  512390001,
#  558097854,
#  559124392,
#  521123033,
#  515385310,
#  560819329,
#  560849438,
#  549748732,
#  559545593,
#  543310781,
#  544626828,
#  555911092,
#  533556767,
#  559664108,
#  515539814,
#  512557910,
#  549133439,
#  513384148,
#  557023082,
#  516024274,
#  555649033,
#  559545593,
#  543475795,
#  523272305,
#  560682805,
#  512390001,
#  542792552,
#  558025810,
#  523221135,
#  560849776,
#  516996143,
#  523548843,
#  548528722,
#  560849584,
#  548581563,
#  559604392,
#  559545593,
#  514706624,
#  560848855,
#  559388349,
#  557023082,
#  560849704,
#  543087918,
#  560813888,
#  513922436,
#  513612105,
#  559664108,
#  560849704,
#  519187634,
#  560850127,
#  560849952,
#  560849584,
#  519588736,
#  555226652,
#  560441021,
#  560850127,
#  552300758,
#  559545593,
#  523221135,
#  544280161,
#  560792066,
#  555026836,
#  560689180,
#  535831497,
#  560849379,
#  555839469,
#  560586322,
#  560850096,
#  550368880,
#  514824222,
#  560848430,
#  542792552,
#  560850127,
#  560846977,
#  552893551,
#  560546349,
#  560441021,
#  560848649,
#  513987005,
#  542792552,
#  560771994,
#  543475795,
#  549133439,
#  548555240,
#  548567755,
#  512557910,
#  551052665,
#  543662993,
#  560849952,
#  514979628,
#  542671639,
#  519951384,
#  538008565,
#  515491725,
#  560848430,
#  557617654,
#  560846977,
#  544923821,
#  513987005,
#  560846512,
#  542792552,
#  560771994,
#  518850925,
#  560850127,
#  ...]

# %%
# 원본 데이터에서 user_id가 위의 user 리스트인 사람 & event_type이 purchase인 경우
df_user = total[(total['user_id'].isin(user)) & (total['event_type'] == 'purchase') ]
df_user
# Out:
#                        event_time event_type  product_id  \
# 178     2019-10-16 12:04:46+00:00   purchase     1005105
# 214     2019-10-16 12:04:48+00:00   purchase     1002544
# 295     2019-10-16 12:04:52+00:00   purchase     1003312
# 479     2019-10-16 12:05:03+00:00   purchase     1005135
# 572     2019-10-16 12:05:07+00:00   purchase     1004835
# ...                           ...        ...         ...
# 7074097 2019-10-11 17:54:18+00:00   purchase     1004249
# 7074469 2019-10-11 17:54:34+00:00   purchase     1003235
# 7074484 2019-10-11 17:54:35+00:00   purchase     1005112
# 7074507 2019-10-11 17:54:35+00:00   purchase     1005115
# 7074511 2019-10-11 17:54:36+00:00   purchase     1002524
#
#                   category_code    brand        price    user_id
# 178      electronics.smartphone    apple  1424.209961  514778102
# 214      electronics.smartphone    apple   460.109985  522354527
# 295      electronics.smartphone    apple   699.799988  517222549
# 479      electronics.smartphone    apple  1741.359985  536590960
# 572      electronics.smartphone  samsung   225.190002  517728689
# ...                         ...      ...          ...        ...
# 7074097  electronics.smartphone    apple   766.760010  559250735
# 7074469  electronics.smartphone   huawei   128.419998  559189082
# 7074484  electronics.smartphone    apple  1003.849976  512404459
# 7074507  electronics.smartphone    apple  1003.849976  540273893
# 7074511  electronics.smartphone    apple   566.960022  533409964
#
# [227791 rows x 7 columns]

# %%
view_max
# Out:
#                   category_code    brand    user_id  product_id
# 3        electronics.smartphone  samsung  515456548     1004833
# 14       electronics.smartphone  samsung  534900903     1004856
# 18       electronics.smartphone  samsung  513747311     1004856
# 49       electronics.smartphone  samsung  560838312     1004856
# 94       electronics.smartphone  samsung  514791097     1004856
# ...                         ...      ...        ...         ...
# 7074661  electronics.smartphone  samsung  542522794     1004856
# 7074702  electronics.smartphone  samsung  518985190     1004767
# 7074704  electronics.smartphone  samsung  516643465     1004833
# 7074706  electronics.smartphone  samsung  559253574     1004856
# 7074740  electronics.smartphone  samsung  520769832     1004767
#
# [1288150 rows x 4 columns]

# %%
pd.merge(view_max, df_user, on=['product_id', 'user_id'], how='inner')['user_id']
# Out:
# 0         560836294
# 1         560836294
# 2         560836294
# 3         514128238
# 4         514128238
#             ...
# 597634    515800764
# 597635    540273893
# 597636    540273893
# 597637    512723560
# 597638    512723560
# Name: user_id, Length: 597639, dtype: int64

# %%
a = pd.merge(view_max, df_user, on=['product_id', 'user_id'], how='inner')
a
# Out:
#                category_code_x  brand_x    user_id  product_id  \
# 0       electronics.smartphone  samsung  560836294     1004856
# 1       electronics.smartphone  samsung  560836294     1004856
# 2       electronics.smartphone  samsung  560836294     1004856
# 3       electronics.smartphone  samsung  514128238     1004856
# 4       electronics.smartphone  samsung  514128238     1004856
# ...                        ...      ...        ...         ...
# 597634  electronics.smartphone    apple  515800764     1005115
# 597635  electronics.smartphone    apple  540273893     1005115
# 597636  electronics.smartphone    apple  540273893     1005115
# 597637  electronics.smartphone  samsung  512723560     1004833
# 597638  electronics.smartphone  samsung  512723560     1004833
#
#                       event_time event_type         category_code_y  brand_y  \
# 0      2019-10-16 12:08:41+00:00   purchase  electronics.smartphone  samsung
# 1      2019-10-16 12:08:41+00:00   purchase  electronics.smartphone  samsung
# 2      2019-10-16 12:08:41+00:00   purchase  electronics.smartphone  samsung
# 3      2019-10-24 05:44:28+00:00   purchase  electronics.smartphone  samsung
# 4      2019-10-24 05:44:28+00:00   purchase  electronics.smartphone  samsung
# ...                          ...        ...                     ...      ...
# 597634 2019-10-11 17:49:22+00:00   purchase  electronics.smartphone    apple
# 597635 2019-10-11 17:54:35+00:00   purchase  electronics.smartphone    apple
# 597636 2019-10-11 17:54:35+00:00   purchase  electronics.smartphone    apple
# 597637 2019-10-11 17:52:37+00:00   purchase  electronics.smartphone  samsung
# 597638 2019-10-11 17:52:37+00:00   purchase  electronics.smartphone  samsung
#
#               price
# 0        131.639999
# 1        131.639999
# 2        131.639999
# 3        131.509995
# 4        131.509995
# ...             ...
# 597634  1003.849976
# 597635  1003.849976
# 597636  1003.849976
# 597637   172.220001
# 597638   172.220001
#
# [597639 rows x 9 columns]

# %%
# view가 top5인 상품을 담은 view_max와 위의 df_user를 결합하여 user_id 추출 
pd.merge(view_max, df_user, on=['product_id', 'user_id'], how='inner')['user_id'].nunique()
# Out:
# 42906

# %%
42906 / 480327* 100 # 8.9%의 user만 구매함
# Out:
# 8.932664622226108

# %%
r = df_reset[['user_id', 'Cluster']]
r
# Out:
#           user_id  Cluster
# 0       384989212        1
# 1       401021311        1
# 2       403013066        3
# 3       410333972        0
# 4       415873351        0
# ...           ...      ...
# 228388  566265448        0
# 228389  566267483        0
# 228390  566270060        0
# 228391  566274637        0
# 228392  566278294        0
#
# [228393 rows x 2 columns]

# %%
i = pd.merge(a, r, on='user_id', how='left')[['user_id', 'Cluster']]
i
# Out:
#           user_id  Cluster
# 0       560836294        1
# 1       560836294        1
# 2       560836294        1
# 3       514128238        1
# 4       514128238        1
# ...           ...      ...
# 597634  515800764        3
# 597635  540273893        3
# 597636  540273893        3
# 597637  512723560        1
# 597638  512723560        1
#
# [597639 rows x 2 columns]

# %%
i.drop_duplicates(['user_id'])['Cluster'].value_counts(1).sort_index()
# Out:
# 0    0.218081
# 1    0.274064
# 2    0.216520
# 3    0.291335
# Name: Cluster, dtype: float64

# %% [markdown]
# ### 장바구니에만 많이 담긴 제품

# %%
# 전체 데이터프레임
total = pd.read_parquet('df_total.parquet.gzip')
total.head()
# Out:
#                  event_time event_type  product_id            category_code  \
# 0 2019-10-16 12:04:37+00:00       view     7900918  furniture.kitchen.chair
# 1 2019-10-16 12:04:37+00:00       view     1003317   electronics.smartphone
# 2 2019-10-16 12:04:37+00:00       view     2501929  appliances.kitchen.oven
# 3 2019-10-16 12:04:37+00:00       view     1004833   electronics.smartphone
# 4 2019-10-16 12:04:37+00:00       cart     1004836   electronics.smartphone
#
#      brand       price    user_id
# 0     joie  102.709999  560842110
# 1    apple  952.150024  560842739
# 2     asel   61.750000  525817175
# 3  samsung  172.169998  515456548
# 4  samsung  229.410004  529758564

# %%
total.shape
# Out:
# (22146517, 7)

# %%
df_cart = total[total['event_type'] == 'cart']
df_cart
# Out:
#                        event_time event_type  product_id  \
# 4       2019-10-16 12:04:37+00:00       cart     1004836
# 64      2019-10-16 12:04:40+00:00       cart     5100562
# 65      2019-10-16 12:04:40+00:00       cart     1201460
# 79      2019-10-16 12:04:41+00:00       cart    45300027
# 87      2019-10-16 12:04:41+00:00       cart     1002524
# ...                           ...        ...         ...
# 7074141 2019-10-11 17:54:20+00:00       cart     6700581
# 7074207 2019-10-11 17:54:23+00:00       cart     1005112
# 7074345 2019-10-11 17:54:29+00:00       cart     8800093
# 7074498 2019-10-11 17:54:35+00:00       cart     8800048
# 7074613 2019-10-11 17:54:40+00:00       cart     3100967
#
#                            category_code    brand        price    user_id
# 4                 electronics.smartphone  samsung   229.410004  529758564
# 64                    electronics.clocks    apple   295.750000  512938489
# 65                    electronics.tablet    apple   514.500000  560842390
# 79                            kids.swing   pituso    89.669998  559176425
# 87                electronics.smartphone    apple   537.719971  525093135
# ...                                  ...      ...          ...        ...
# 7074141  computers.components.videocards    palit   165.279999  516001171
# 7074207           electronics.smartphone    apple  1003.849976  542072341
# 7074345            electronics.telephone    nokia    50.189999  539136718
# 7074498            electronics.telephone    nokia    22.250000  558723618
# 7074613       appliances.kitchen.blender  kitfort    52.240002  546975953
#
# [643372 rows x 7 columns]

# %%
df_cart.groupby(['product_id'])[['user_id']].count().sort_values(by='user_id', ascending=False)
# Out:
#             user_id
# product_id
# 1004856       41201
# 1004767       29802
# 4804056       18300
# 1004833       17012
# 1004870       15500
# ...             ...
# 2800658           1
# 9900224           1
# 1701029           1
# 9900161           1
# 4000150           1
#
# [6391 rows x 1 columns]

# %%
# product_id 구하기
idx = df_cart.groupby(['product_id'])[['user_id']].count().sort_values(by='user_id', ascending=False).head().index
idx
# Out:
# Int64Index([1004856, 1004767, 4804056, 1004833, 1004870], dtype='int64', name='product_id')

# %%
idx = idx.to_list()

# %%
cart_max = df_cart[df_cart['product_id'].isin(idx)][['category_code', 'brand', 'user_id','product_id']]
cart_max
# Out:
#                        category_code    brand    user_id  product_id
# 92            electronics.smartphone  samsung  560838312     1004856
# 418           electronics.smartphone  samsung  529278312     1004767
# 492           electronics.smartphone  samsung  560836294     1004856
# 551      electronics.audio.headphone    apple  557484115     4804056
# 591           electronics.smartphone  samsung  518856168     1004833
# ...                              ...      ...        ...         ...
# 7071001       electronics.smartphone  samsung  512723560     1004833
# 7071434       electronics.smartphone  samsung  516853554     1004767
# 7071606       electronics.smartphone  samsung  521640125     1004767
# 7071676       electronics.smartphone  samsung  516853554     1004767
# 7072520       electronics.smartphone  samsung  559252706     1004856
#
# [121815 rows x 4 columns]

# %%
cart_max['category_code'].value_counts(1).plot.bar(rot=0) # smartphone, audio.headphone
# Out:
# <Axes: >

# %%
cart_max['brand'].value_counts(1).plot.bar(rot=0) # samsumg, apple 순으로 높음
# Out:
# <Axes: >

# %%
total[total['category_code'] == 'electronics.audio.headphone']['brand'].unique()
# Out:
# array(['apple', 'huawei', 'samsung', 'xiaomi', 'harper', 'jbl', 'olmio',
#        'sony', 'canyon', 'jabra', 'elari', 'bose', 'defender',
#        'plantronics', 'panasonic', 'hoco', 'sennheiser', 'hyperx',
#        'marley', 'koss', 'audio-technica', 'usams', 'logitech',
#        'marshall', 'acme', 'awei', 'manhattan', 'razer', 'hp', 'trust',
#        'ritmix', 'acqua', 'inkax', 'steelseries', 'akg', 'olto', 'rapoo',
#        'beats', 'microlab', 'acer', 'meizu', 'global', 'philips',
#        'kingston', 'lenovo', 'asus', 'nokia', 'fiio', 'yamaha', 'dunu',
#        'remax', 'edifier', 'redragon', 'denn', 'shure', 'beyerdynamic',
#        'parrot', 'cowon', 'sven', 'joyroom', 'vox', 'ergo', 'intro',
#        'cnd', 'wuw', 'havit', 'fender', 'honor', 'soundking', 'alesis',
#        'behringer', 'orico', 'samson', 'superlux', 'fostex', 'crown',
#        'jvc', 'pioneer', 'hercules', 'genius', 'urbanears', 'gembird',
#        'rombica', 'qcyber', 'lg', 'ipipoo', 'recci', 'continent', 'veho',
#        'monster', 'skullcandy', 'delux', 'bluedio', 'gamemax', 'gigabyte',
#        'creative', 'hifiman', 'g-cube', 'siee', 'presonus', 'numark',
#        'magnat', 'casio', 'westone', 'm-audio', 'proel', 'msi', 'nuforce',
#        'zalman', 'sades', 'roland', 'mark', 'fly', 'avermedia',
#        'verbatim', 'gamdias', 'krk', 'alctron', 'tascam', 'microsoft',
#        'ultrasone', 'celebrat', 'tesoro', 't.bone', 'yison', 'nobby'],
#       dtype=object)

# %% [markdown]
# ### 장바구니에 많이 담은 제품 top5에 해당하는 user들이 구매는 안 했을까?

# %%
# cart top5에 해당하는 제품들을 본 총 사용자 수
cart_max['user_id'].nunique()
# Out:
# 56438

# %%
# 리스트로 변환
user = cart_max['user_id'].to_list()
user
# Out:
# [560838312,
#  529278312,
#  560836294,
#  557484115,
#  518856168,
#  524922149,
#  512508879,
#  560843235,
#  513747311,
#  543141199,
#  515427976,
#  526914855,
#  549717525,
#  549717525,
#  554416727,
#  516048316,
#  514669514,
#  513747311,
#  526914855,
#  529333488,
#  560844223,
#  512508879,
#  546986785,
#  517859784,
#  535702917,
#  536016675,
#  528283014,
#  560843868,
#  525608960,
#  535097033,
#  516524487,
#  523944249,
#  520015249,
#  560844554,
#  528373101,
#  551971075,
#  514232447,
#  553825721,
#  552386415,
#  560501516,
#  521036000,
#  533094928,
#  560501516,
#  560845210,
#  543191801,
#  553974309,
#  560845210,
#  551158498,
#  560845210,
#  556663534,
#  560441021,
#  560845508,
#  536383145,
#  542190737,
#  542190737,
#  553825721,
#  549437637,
#  514979628,
#  560845568,
#  560786127,
#  517923866,
#  560843361,
#  545180465,
#  543103791,
#  512378015,
#  543103791,
#  550225952,
#  551321134,
#  545180465,
#  520359588,
#  551321134,
#  549169760,
#  512419524,
#  559200025,
#  553974309,
#  559200025,
#  560846535,
#  520359588,
#  549437637,
#  525146522,
#  560841430,
#  513518034,
#  559200025,
#  559200025,
#  559200025,
#  535573036,
#  560846872,
#  560846872,
#  523944249,
#  524094622,
#  560389943,
#  524094622,
#  543191801,
#  549332732,
#  550200726,
#  521586440,
#  541822903,
#  549169760,
#  537076709,
#  516024274,
#  516524487,
#  560841430,
#  529863594,
#  518620607,
#  514193503,
#  529699061,
#  536383145,
#  525690046,
#  542140087,
#  519236048,
#  516551650,
#  553825721,
#  560843361,
#  529863594,
#  560848323,
#  515628249,
#  536383145,
#  529699061,
#  560813888,
#  540360826,
#  529699061,
#  522557542,
#  558887315,
#  558887315,
#  529699061,
#  521454023,
#  548132948,
#  529699061,
#  523804628,
#  529699061,
#  552723900,
#  560846535,
#  529699061,
#  549584746,
#  559371251,
#  549476802,
#  557236864,
#  554387483,
#  560767105,
#  554387483,
#  556663534,
#  557236864,
#  512419524,
#  529088810,
#  549437637,
#  514899552,
#  512419524,
#  521123033,
#  551975393,
#  519236048,
#  534230110,
#  521123033,
#  560841233,
#  552305623,
#  559978538,
#  560841430,
#  555649033,
#  514465275,
#  559978538,
#  560813888,
#  559388349,
#  542792552,
#  514979628,
#  513987005,
#  552893551,
#  542792552,
#  560843361,
#  544280161,
#  532365682,
#  522156961,
#  560850451,
#  531104219,
#  560848596,
#  530600764,
#  513987005,
#  521454023,
#  516524487,
#  549933602,
#  522124226,
#  560209795,
#  549332732,
#  543087918,
#  560850743,
#  543087918,
#  556580519,
#  556027426,
#  521454023,
#  516519464,
#  532561790,
#  556663534,
#  543087918,
#  543087918,
#  551117579,
#  557243644,
#  543646923,
#  549933602,
#  549227115,
#  558452394,
#  542792552,
#  560812141,
#  558452394,
#  536408158,
#  523265503,
#  514979628,
#  522124226,
#  560560755,
#  512713506,
#  551673634,
#  526146923,
#  512390001,
#  560546349,
#  514480768,
#  514611480,
#  512713506,
#  530600764,
#  546446267,
#  557350899,
#  542792552,
#  514611480,
#  543087918,
#  518802367,
#  560846535,
#  514611480,
#  558752908,
#  558878439,
#  512713506,
#  542792552,
#  521454023,
#  535702917,
#  521454023,
#  560841233,
#  553857893,
#  521454023,
#  521454023,
#  560850451,
#  532046455,
#  521454023,
#  521454023,
#  521454023,
#  560369236,
#  521454023,
#  521454023,
#  521454023,
#  551673634,
#  521454023,
#  521454023,
#  516397749,
#  521454023,
#  560846977,
#  521454023,
#  521454023,
#  521454023,
#  521454023,
#  521454023,
#  560841233,
#  558878439,
#  546446267,
#  552809764,
#  538440830,
#  555157663,
#  560106023,
#  560853383,
#  513747311,
#  516516695,
#  516516695,
#  516516695,
#  519449858,
#  560217529,
#  521454023,
#  560217529,
#  512930925,
#  559926324,
#  512930925,
#  544585757,
#  546179063,
#  551673634,
#  540393497,
#  515596490,
#  559926324,
#  551673634,
#  525780837,
#  557643049,
#  551673634,
#  516996143,
#  560840698,
#  560155105,
#  550225952,
#  560846977,
#  541181284,
#  541181284,
#  558998701,
#  560767105,
#  516507041,
#  529884614,
#  518608506,
#  516996143,
#  555627617,
#  555627617,
#  516996143,
#  555599010,
#  516507041,
#  550041702,
#  551673634,
#  526121840,
#  560854461,
#  560155105,
#  541025276,
#  560854761,
#  560767105,
#  550041702,
#  515143253,
#  519025253,
#  512883096,
#  512713506,
#  541350679,
#  530600764,
#  555599010,
#  519025253,
#  557586489,
#  541331108,
#  560855143,
#  527329918,
#  560854805,
#  560855559,
#  525976727,
#  560855663,
#  513987005,
#  560855335,
#  560372362,
#  515793486,
#  523222483,
#  518894768,
#  513593925,
#  554417389,
#  560729276,
#  515463475,
#  526121840,
#  554417389,
#  554417389,
#  537632707,
#  560855143,
#  531502926,
#  519025253,
#  513511660,
#  525565358,
#  513042129,
#  545765367,
#  512713506,
#  518064527,
#  514706624,
#  560854555,
#  560855231,
#  560854555,
#  560854555,
#  537632707,
#  513917077,
#  560729276,
#  520644332,
#  513917077,
#  541331108,
#  512929457,
#  525817717,
#  559709250,
#  551388041,
#  546841305,
#  558760708,
#  512776116,
#  521363501,
#  521363501,
#  525817717,
#  527329918,
#  547751322,
#  547574131,
#  558760708,
#  560857753,
#  547751322,
#  558760708,
#  518773214,
#  527329918,
#  549745659,
#  541883738,
#  527410411,
#  525817717,
#  519472599,
#  560857235,
#  549499312,
#  514783802,
#  550675651,
#  551388041,
#  520819941,
#  516297799,
#  560858310,
#  536643562,
#  545828093,
#  556271370,
#  556991621,
#  560858859,
#  560858859,
#  556991621,
#  556297894,
#  526558229,
#  548581563,
#  556297894,
#  514706624,
#  556297894,
#  560858859,
#  556297894,
#  526558229,
#  549437637,
#  560859103,
#  528348896,
#  560053649,
#  548581563,
#  560858457,
#  546179063,
#  544406041,
#  556109115,
#  560857089,
#  559192491,
#  525966590,
#  549437637,
#  541775229,
#  558999650,
#  540746250,
#  541883738,
#  556271370,
#  555975769,
#  512933657,
#  515351502,
#  523984980,
#  560858859,
#  514802244,
#  544406041,
#  533528721,
#  533528721,
#  547747691,
#  520819941,
#  522460833,
#  560053649,
#  518972707,
#  550225952,
#  516311659,
#  560046032,
#  537157728,
#  537183788,
#  533447690,
#  524370224,
#  516615157,
#  560610423,
#  515146579,
#  532964770,
#  512713506,
#  560345682,
#  560046032,
#  532964770,
#  550225952,
#  537183788,
#  559419389,
#  560692011,
#  537183788,
#  541883738,
#  559898063,
#  560860736,
#  560840698,
#  512885710,
#  560860618,
#  537157728,
#  549360884,
#  513199581,
#  541331108,
#  524399723,
#  518199743,
#  524882720,
#  549125507,
#  560861466,
#  537157728,
#  522095286,
#  533192286,
#  558485337,
#  528415736,
#  560860967,
#  527613249,
#  560046032,
#  514770711,
#  560046032,
#  514802244,
#  541331108,
#  549360884,
#  537157728,
#  560861623,
#  560861700,
#  530278581,
#  560861700,
#  559898063,
#  560860982,
#  560861486,
#  558558377,
#  559462165,
#  549360884,
#  547138226,
#  537157728,
#  555521084,
#  533192286,
#  548924386,
#  560366020,
#  515867290,
#  529150133,
#  560860982,
#  543380791,
#  560857235,
#  560857235,
#  559898063,
#  555521084,
#  529150133,
#  557591670,
#  560858859,
#  560862222,
#  559021292,
#  560862222,
#  560861466,
#  529150133,
#  549125507,
#  560860894,
#  560860967,
#  515112143,
#  529150133,
#  560859180,
#  560862674,
#  515867290,
#  543380791,
#  515092748,
#  514589297,
#  514589297,
#  527219358,
#  527219358,
#  559419389,
#  560861466,
#  541179678,
#  541730173,
#  551997145,
#  560863070,
#  560861916,
#  541730173,
#  543380791,
#  525791102,
#  517466946,
#  560863218,
#  560863070,
#  556664053,
#  559699875,
#  514770711,
#  560858999,
#  554985342,
#  527219358,
#  558998701,
#  560860967,
#  532075073,
#  554985342,
#  560858999,
#  552444404,
#  533170018,
#  543380791,
#  537183788,
#  515363715,
#  541730173,
#  533170018,
#  560861466,
#  554985342,
#  556664053,
#  560863892,
#  522566415,
#  522566415,
#  529661725,
#  517647386,
#  513282129,
#  544010927,
#  544010927,
#  544010927,
#  518198922,
#  543356214,
#  558179253,
#  542079564,
#  542280158,
#  559699875,
#  549525695,
#  560840698,
#  552494128,
#  548749208,
#  542877405,
#  542877405,
#  523375473,
#  517430845,
#  551618278,
#  548749208,
#  512423600,
#  544045866,
#  560840698,
#  516504366,
#  542340954,
#  541655262,
#  533560641,
#  524704777,
#  560860701,
#  523944249,
#  541655262,
#  545491611,
#  521922082,
#  560866224,
#  514929431,
#  537442554,
#  533560641,
#  519659731,
#  548749208,
#  560860982,
#  515855156,
#  559699875,
#  560865633,
#  518452686,
#  560711840,
#  515525091,
#  546038336,
#  515855156,
#  542877405,
#  541730173,
#  513811287,
#  521922082,
#  560700540,
#  521451245,
#  559699875,
#  513335534,
#  530167464,
#  559056974,
#  559056974,
#  513806498,
#  547605035,
#  513811287,
#  513811287,
#  516365775,
#  538441364,
#  516365775,
#  545907806,
#  560867728,
#  553833295,
#  544967317,
#  559699875,
#  560700540,
#  549689614,
#  560867866,
#  546801526,
#  553008664,
#  559089805,
#  560868031,
#  551975319,
#  560700540,
#  551975319,
#  560867534,
#  543644482,
#  560867866,
#  512473121,
#  559699875,
#  549689614,
#  541730173,
#  535080719,
#  560860982,
#  513416861,
#  518009998,
#  559699875,
#  560868207,
#  530167464,
#  541730173,
#  513416861,
#  515143958,
#  541730173,
#  513340870,
#  539287271,
#  560868825,
#  535080719,
#  560868825,
#  515855156,
#  515355878,
#  546540478,
#  515855156,
#  513749662,
#  559099376,
#  515855156,
#  560868754,
#  546109989,
#  520092557,
#  513137195,
#  523840832,
#  522766907,
#  525243554,
#  524460292,
#  512951619,
#  560700540,
#  557972339,
#  554985342,
#  560869798,
#  515855156,
#  512951619,
#  518578084,
#  540587390,
#  516805690,
#  560869798,
#  550699267,
#  515143958,
#  514480768,
#  555227455,
#  529332147,
#  549134731,
#  520092557,
#  521530748,
#  519063232,
#  517307464,
#  555227455,
#  524189673,
#  560870524,
#  560800765,
#  512951619,
#  514480768,
#  555070326,
#  521530748,
#  560870494,
#  546988515,
#  529332147,
#  524532998,
#  555227455,
#  548143176,
#  554658666,
#  516397749,
#  512951619,
#  560871425,
#  549525695,
#  538432579,
#  535886806,
#  558485337,
#  554441861,
#  558485337,
#  534546385,
#  558485337,
#  530167464,
#  517504270,
#  558722374,
#  555041114,
#  560150371,
#  535022692,
#  553458749,
#  544314037,
#  549228194,
#  514232447,
#  556833478,
#  560532609,
#  541730173,
#  544608048,
#  514232447,
#  549228194,
#  544314037,
#  548220696,
#  560872259,
#  560840698,
#  548220696,
#  552832813,
#  554985342,
#  548220696,
#  523992881,
#  534321337,
#  555227455,
#  512951619,
#  560872173,
#  560872630,
#  560872990,
#  514731302,
#  560872173,
#  560872061,
#  560872061,
#  543196263,
#  554985342,
#  549460482,
#  555715032,
#  560872209,
#  546452393,
#  558881904,
#  521484258,
#  519629806,
#  515961428,
#  560700540,
#  548746881,
#  559044469,
#  522168217,
#  515248363,
#  560582251,
#  560582251,
#  547495123,
#  557025362,
#  560873702,
#  535022692,
#  558276944,
#  558276944,
#  538669939,
#  559653128,
#  560857262,
#  519264959,
#  555715032,
#  547344235,
#  517504270,
#  552494386,
#  512573440,
#  559653128,
#  519264959,
#  554837656,
#  555715032,
#  515794957,
#  514480768,
#  512704896,
#  514333786,
#  512704896,
#  516389154,
#  521786204,
#  517504270,
#  525323756,
#  533109533,
#  529670915,
#  514333786,
#  514333786,
#  546858691,
#  512918678,
#  514266451,
#  541682538,
#  556609894,
#  536831816,
#  559007187,
#  560857262,
#  527015837,
#  530118330,
#  512439739,
#  543462403,
#  533109533,
#  515201524,
#  525393527,
#  533314827,
#  560876116,
#  512439739,
#  530118330,
#  549341528,
#  542140391,
#  523944249,
#  530167464,
#  547696103,
#  523944249,
#  549618244,
#  552272105,
#  523944249,
#  543462403,
#  524188542,
#  524188542,
#  549618244,
#  554985342,
#  528059142,
#  535055855,
#  559342539,
#  538351663,
#  560145343,
#  536095508,
#  559342539,
#  554985342,
#  549618244,
#  522168217,
#  560873885,
#  517874712,
#  529358170,
#  550960908,
#  560876400,
#  545580984,
#  538733044,
#  559699875,
#  540383567,
#  544720994,
#  559699875,
#  535055855,
#  546043336,
#  516038342,
#  518689661,
#  540383567,
#  519727237,
#  512887728,
#  556694102,
#  560876819,
#  538527633,
#  512887728,
#  521688527,
#  523276628,
#  517413944,
#  521688527,
#  517413944,
#  517413944,
#  560879552,
#  529902807,
#  529902807,
#  555975769,
#  545538770,
#  548090725,
#  535516067,
#  527984837,
#  529902807,
#  544344690,
#  529902807,
#  529902807,
#  559695005,
#  560145343,
#  512875789,
#  524782815,
#  560880343,
#  546052260,
#  547149358,
#  559695005,
#  512875789,
#  560532572,
#  556404342,
#  530368319,
#  554985342,
#  512390122,
#  512875789,
#  527846686,
#  560880976,
#  560879208,
#  558575803,
#  542734621,
#  547321849,
#  530701197,
#  518689661,
#  559007187,
#  519480990,
#  514280162,
#  537442557,
#  558575803,
#  540203345,
#  559402315,
#  547305466,
#  530701197,
#  527907769,
#  513825240,
#  530538895,
#  560046032,
#  560840698,
#  512800546,
#  518452272,
#  527907769,
#  560838789,
#  547305466,
#  525646957,
#  530538895,
#  560880976,
#  527354201,
#  548742644,
#  525646957,
#  530701197,
#  560840698,
#  557770351,
#  557770351,
#  525646957,
#  557770351,
#  557770351,
#  560879208,
#  557770351,
#  536976268,
#  557770351,
#  517911351,
#  520207858,
#  527354201,
#  557770351,
#  543195320,
#  560880976,
#  525646957,
#  550397952,
#  560881888,
#  525646957,
#  560881888,
#  560879208,
#  517413944,
#  517413944,
#  518689661,
#  555930223,
#  525646957,
#  535396874,
#  546197034,
#  560882246,
#  546197034,
#  560881888,
#  545939843,
#  517911351,
#  560881888,
#  560879208,
#  560882246,
#  525646957,
#  518939932,
#  558851331,
#  515706387,
#  560880976,
#  546208941,
#  560881714,
#  ...]

# %%
# 원본 데이터에서 user_id가 위의 user 리스트에 있는 사람 & event_type이 purchase인 경우를 추출
df_user = total[(total['user_id'].isin(user)) & (total['event_type'] == 'purchase')]
df_user
# Out:
#                        event_time event_type  product_id  \
# 214     2019-10-16 12:04:48+00:00   purchase     1002544
# 295     2019-10-16 12:04:52+00:00   purchase     1003312
# 572     2019-10-16 12:05:07+00:00   purchase     1004835
# 907     2019-10-16 12:05:23+00:00   purchase     1004856
# 1095    2019-10-16 12:05:33+00:00   purchase     1004833
# ...                           ...        ...         ...
# 7072250 2019-10-11 17:52:57+00:00   purchase     1004767
# 7072641 2019-10-11 17:53:14+00:00   purchase     1004856
# 7073793 2019-10-11 17:54:05+00:00   purchase     1004785
# 7073974 2019-10-11 17:54:12+00:00   purchase     1004962
# 7074469 2019-10-11 17:54:34+00:00   purchase     1003235
#
#                   category_code    brand       price    user_id
# 214      electronics.smartphone    apple  460.109985  522354527
# 295      electronics.smartphone    apple  699.799988  517222549
# 572      electronics.smartphone  samsung  225.190002  517728689
# 907      electronics.smartphone  samsung  131.639999  548518784
# 1095     electronics.smartphone  samsung  172.169998  518856168
# ...                         ...      ...         ...        ...
# 7072250  electronics.smartphone  samsung  250.880005  518902557
# 7072641  electronics.smartphone  samsung  130.479996  558845757
# 7073793  electronics.smartphone   huawei  272.049988  559132868
# 7073974  electronics.smartphone    nokia  128.490005  553843399
# 7074469  electronics.smartphone   huawei  128.419998  559189082
#
# [114183 rows x 7 columns]

# %%
pd.merge(cart_max, df_user, on=['product_id', 'user_id'], how='inner')['user_id'].nunique()
# Out:
# 34110

# %%
34110 / 56438 * 100
# Out:
# 60.43800276409511

# %% [markdown]
# 2) 집단별로는?

# %%
a = pd.merge(cart_max, df_user, on=['product_id', 'user_id'], how='inner')
r = df_reset[['user_id', 'Cluster']]

# %%
i = pd.merge(a, r, on='user_id', how='left')[['user_id', 'Cluster']]

# %%
i.drop_duplicates(['user_id'])['Cluster'].value_counts(1).sort_index()
# Out:
# 0    0.227968
# 1    0.354559
# 2    0.198446
# 3    0.219027
# Name: Cluster, dtype: float64

# %%
i.drop_duplicates(['user_id'])['Cluster'].value_counts(1).sort_index().plot.bar(rot=0)
# Out:
# <Axes: >

# %% [markdown]
# ### 집단별 많이 구매한 브랜드 or 카테고리
# #### 0번 집단

# %%
clu0 = df[df['Cluster'] == 0]
clu0
# Out:
#            Recency  Frequency  MonetaryValue  R  F  M RFM_segment  RFM_score  \
# user_id
# 410333972        1          1     591.250000  5  1  4         514         10
# 415873351        1          2     263.059998  5  4  3         543         12
# 418115333        4          1     127.419998  5  1  1         511          7
# 430524990        3          1     130.990005  5  1  1         511          7
# 431897261        4          1     463.329987  5  1  4         514         10
# ...            ...        ...            ... .. .. ..         ...        ...
# 566265448        1          1     592.010010  5  4  4         544         13
# 566267483        1          2      30.740000  5  5  1         551         11
# 566270060        1          2     147.419998  5  5  2         552         12
# 566274637        1          1    2011.630005  5  4  5         545         14
# 566278294        1          1    1661.089966  5  4  5         545         14
#
#           RFM_class  Cluster
# user_id
# 410333972      gold        0
# 415873351  platinum        0
# 418115333    silver        0
# 430524990    silver        0
# 431897261      gold        0
# ...             ...      ...
# 566265448  platinum        0
# 566267483  platinum        0
# 566270060  platinum        0
# 566274637  platinum        0
# 566278294  platinum        0
#
# [55713 rows x 10 columns]

# %%
clu0['RFM_class'].value_counts(1).plot.bar(rot=0) # 0번 클러스터에는 platinum 고객이 많음
# Out:
# <Axes: >

# %%
clu0 = clu0.reset_index()
clu0
# Out:
#          user_id  Recency  Frequency  MonetaryValue  R  F  M RFM_segment  \
# 0      410333972        1          1     591.250000  5  1  4         514
# 1      415873351        1          2     263.059998  5  4  3         543
# 2      418115333        4          1     127.419998  5  1  1         511
# 3      430524990        3          1     130.990005  5  1  1         511
# 4      431897261        4          1     463.329987  5  1  4         514
# ...          ...      ...        ...            ... .. .. ..         ...
# 55708  566265448        1          1     592.010010  5  4  4         544
# 55709  566267483        1          2      30.740000  5  5  1         551
# 55710  566270060        1          2     147.419998  5  5  2         552
# 55711  566274637        1          1    2011.630005  5  4  5         545
# 55712  566278294        1          1    1661.089966  5  4  5         545
#
#        RFM_score RFM_class  Cluster
# 0             10      gold        0
# 1             12  platinum        0
# 2              7    silver        0
# 3              7    silver        0
# 4             10      gold        0
# ...          ...       ...      ...
# 55708         13  platinum        0
# 55709         11  platinum        0
# 55710         12  platinum        0
# 55711         14  platinum        0
# 55712         14  platinum        0
#
# [55713 rows x 11 columns]

# %%
idx0 = clu0['user_id'].to_list()
idx0
# Out:
# [410333972,
#  415873351,
#  418115333,
#  430524990,
#  431897261,
#  447698613,
#  451868425,
#  453908841,
#  454959751,
#  455460477,
#  456575945,
#  456810531,
#  458020849,
#  458133649,
#  458443142,
#  461956439,
#  467576236,
#  468464006,
#  479307253,
#  480434060,
#  480835273,
#  481341715,
#  481620504,
#  482823034,
#  484195427,
#  484811215,
#  485299568,
#  486098806,
#  488592340,
#  491162210,
#  492719150,
#  499012015,
#  502104092,
#  503626366,
#  504373723,
#  508923534,
#  510193446,
#  510374704,
#  511410651,
#  511865542,
#  512363600,
#  512363650,
#  512363780,
#  512363802,
#  512363867,
#  512364184,
#  512364410,
#  512364484,
#  512364528,
#  512364767,
#  512364795,
#  512364888,
#  512364977,
#  512365272,
#  512365322,
#  512365599,
#  512365639,
#  512365674,
#  512366029,
#  512366225,
#  512366308,
#  512366358,
#  512366907,
#  512366949,
#  512366962,
#  512367258,
#  512367687,
#  512367935,
#  512367979,
#  512368119,
#  512368388,
#  512368966,
#  512368992,
#  512369579,
#  512369908,
#  512370260,
#  512370324,
#  512370780,
#  512370829,
#  512370970,
#  512371084,
#  512371416,
#  512371638,
#  512371743,
#  512371951,
#  512372136,
#  512372414,
#  512372455,
#  512372529,
#  512372683,
#  512372691,
#  512372799,
#  512372876,
#  512372912,
#  512373126,
#  512373132,
#  512373214,
#  512373271,
#  512373495,
#  512373726,
#  512373738,
#  512373843,
#  512373931,
#  512374114,
#  512374194,
#  512374352,
#  512374428,
#  512374551,
#  512374930,
#  512375334,
#  512375391,
#  512375419,
#  512375487,
#  512375522,
#  512375901,
#  512376181,
#  512376234,
#  512376239,
#  512376296,
#  512376329,
#  512376360,
#  512377110,
#  512377119,
#  512377458,
#  512377477,
#  512377528,
#  512377540,
#  512378042,
#  512378315,
#  512378735,
#  512378892,
#  512378970,
#  512379231,
#  512379438,
#  512380070,
#  512380433,
#  512380514,
#  512380716,
#  512380924,
#  512381198,
#  512381616,
#  512382141,
#  512382434,
#  512382480,
#  512382878,
#  512383010,
#  512383127,
#  512383389,
#  512383662,
#  512383690,
#  512383691,
#  512384207,
#  512384425,
#  512384711,
#  512385284,
#  512385308,
#  512385385,
#  512385518,
#  512385772,
#  512385803,
#  512385928,
#  512386032,
#  512386041,
#  512386166,
#  512386623,
#  512386656,
#  512387516,
#  512387617,
#  512387740,
#  512387840,
#  512388143,
#  512388209,
#  512388301,
#  512388342,
#  512388497,
#  512388535,
#  512388751,
#  512388920,
#  512389195,
#  512389317,
#  512389563,
#  512389773,
#  512390063,
#  512390122,
#  512390159,
#  512390251,
#  512390383,
#  512390519,
#  512390924,
#  512390934,
#  512390979,
#  512391370,
#  512391883,
#  512392273,
#  512392304,
#  512393336,
#  512393364,
#  512393459,
#  512393545,
#  512393698,
#  512393716,
#  512394015,
#  512394547,
#  512394627,
#  512394672,
#  512394905,
#  512395041,
#  512395275,
#  512395335,
#  512395599,
#  512396054,
#  512396283,
#  512396347,
#  512396364,
#  512396560,
#  512396617,
#  512396829,
#  512396834,
#  512396945,
#  512397124,
#  512397198,
#  512397244,
#  512397259,
#  512397359,
#  512397363,
#  512397768,
#  512397888,
#  512397894,
#  512398081,
#  512398141,
#  512398172,
#  512398332,
#  512398587,
#  512398947,
#  512399004,
#  512399231,
#  512399539,
#  512400220,
#  512400391,
#  512400497,
#  512400592,
#  512400710,
#  512401049,
#  512401181,
#  512401321,
#  512401560,
#  512401906,
#  512402043,
#  512402279,
#  512402573,
#  512402639,
#  512402665,
#  512402725,
#  512403091,
#  512403711,
#  512404495,
#  512404581,
#  512404661,
#  512404758,
#  512405099,
#  512405206,
#  512405353,
#  512405456,
#  512405501,
#  512405509,
#  512405575,
#  512405833,
#  512405921,
#  512405956,
#  512405965,
#  512406294,
#  512406367,
#  512406373,
#  512406501,
#  512406522,
#  512406731,
#  512406890,
#  512407488,
#  512407552,
#  512407957,
#  512407984,
#  512408489,
#  512408522,
#  512408597,
#  512408602,
#  512408796,
#  512408977,
#  512409055,
#  512410282,
#  512410317,
#  512410524,
#  512410620,
#  512410645,
#  512410770,
#  512410860,
#  512411488,
#  512412123,
#  512412345,
#  512412567,
#  512412699,
#  512413530,
#  512413715,
#  512414384,
#  512414566,
#  512414845,
#  512415529,
#  512415556,
#  512415731,
#  512415773,
#  512415865,
#  512416052,
#  512416245,
#  512416367,
#  512416517,
#  512416579,
#  512416702,
#  512417059,
#  512417128,
#  512417347,
#  512417625,
#  512417857,
#  512417883,
#  512418204,
#  512418222,
#  512418471,
#  512418544,
#  512418607,
#  512418634,
#  512418838,
#  512419229,
#  512419327,
#  512419391,
#  512419537,
#  512419572,
#  512419627,
#  512419765,
#  512419840,
#  512420226,
#  512420568,
#  512420823,
#  512420863,
#  512420897,
#  512421122,
#  512421160,
#  512421399,
#  512421607,
#  512421626,
#  512421786,
#  512421807,
#  512421884,
#  512422965,
#  512422986,
#  512423193,
#  512423437,
#  512423715,
#  512423726,
#  512424014,
#  512424173,
#  512424305,
#  512425650,
#  512425684,
#  512425891,
#  512426425,
#  512426765,
#  512427273,
#  512427334,
#  512427535,
#  512427834,
#  512427850,
#  512427991,
#  512428382,
#  512428409,
#  512428410,
#  512428532,
#  512428662,
#  512428850,
#  512429031,
#  512429417,
#  512429687,
#  512430246,
#  512430406,
#  512430659,
#  512430872,
#  512431561,
#  512431772,
#  512431781,
#  512431922,
#  512432621,
#  512432850,
#  512433319,
#  512433516,
#  512433550,
#  512433589,
#  512433687,
#  512433840,
#  512433911,
#  512433931,
#  512433933,
#  512433998,
#  512434196,
#  512435212,
#  512435311,
#  512435446,
#  512435491,
#  512435513,
#  512435941,
#  512436111,
#  512436230,
#  512436298,
#  512436841,
#  512436851,
#  512437530,
#  512437905,
#  512438065,
#  512438103,
#  512438294,
#  512438403,
#  512438602,
#  512438978,
#  512439186,
#  512439323,
#  512439396,
#  512439721,
#  512440651,
#  512440781,
#  512441558,
#  512441701,
#  512442079,
#  512442432,
#  512442599,
#  512442857,
#  512443509,
#  512443820,
#  512444081,
#  512444135,
#  512444191,
#  512445025,
#  512445415,
#  512445523,
#  512445975,
#  512446669,
#  512446922,
#  512447681,
#  512447791,
#  512447906,
#  512448185,
#  512448212,
#  512448368,
#  512448683,
#  512448931,
#  512449670,
#  512449844,
#  512449931,
#  512449940,
#  512450233,
#  512450474,
#  512450494,
#  512450539,
#  512450963,
#  512450981,
#  512451210,
#  512451692,
#  512451853,
#  512451987,
#  512452569,
#  512452577,
#  512452626,
#  512452949,
#  512453348,
#  512453904,
#  512453967,
#  512454335,
#  512454355,
#  512455292,
#  512455399,
#  512455450,
#  512455888,
#  512455954,
#  512456332,
#  512456519,
#  512456686,
#  512457234,
#  512457399,
#  512457479,
#  512457629,
#  512457761,
#  512457814,
#  512458159,
#  512458363,
#  512458438,
#  512458831,
#  512458895,
#  512459023,
#  512459049,
#  512459170,
#  512459204,
#  512459421,
#  512459435,
#  512460091,
#  512460164,
#  512460240,
#  512460311,
#  512460492,
#  512460805,
#  512460884,
#  512460957,
#  512461044,
#  512461179,
#  512461357,
#  512461378,
#  512461752,
#  512461930,
#  512462250,
#  512462303,
#  512462322,
#  512462542,
#  512462624,
#  512462692,
#  512462705,
#  512462972,
#  512463048,
#  512463191,
#  512463797,
#  512463916,
#  512463951,
#  512464436,
#  512464805,
#  512465038,
#  512465492,
#  512465600,
#  512465807,
#  512465858,
#  512465888,
#  512466198,
#  512466330,
#  512466538,
#  512466552,
#  512466745,
#  512466848,
#  512466903,
#  512466961,
#  512467048,
#  512467274,
#  512468851,
#  512469067,
#  512469303,
#  512469625,
#  512469644,
#  512469937,
#  512470254,
#  512470317,
#  512470377,
#  512470633,
#  512470802,
#  512470812,
#  512470896,
#  512471052,
#  512471319,
#  512471321,
#  512471519,
#  512471654,
#  512471670,
#  512472053,
#  512472070,
#  512472130,
#  512472214,
#  512472411,
#  512472416,
#  512472517,
#  512472605,
#  512472720,
#  512472766,
#  512472839,
#  512472953,
#  512473320,
#  512473766,
#  512474289,
#  512474318,
#  512475037,
#  512475056,
#  512475182,
#  512475207,
#  512475231,
#  512476408,
#  512476454,
#  512477800,
#  512478099,
#  512478241,
#  512478281,
#  512478582,
#  512479016,
#  512479084,
#  512479212,
#  512479236,
#  512479272,
#  512479743,
#  512479859,
#  512479868,
#  512480265,
#  512481154,
#  512481348,
#  512481602,
#  512481669,
#  512481977,
#  512482114,
#  512482258,
#  512482694,
#  512482724,
#  512482905,
#  512482974,
#  512483146,
#  512483190,
#  512483551,
#  512483893,
#  512484022,
#  512484504,
#  512484727,
#  512485044,
#  512485373,
#  512485410,
#  512485424,
#  512485691,
#  512485723,
#  512485884,
#  512486070,
#  512486122,
#  512486230,
#  512486258,
#  512486320,
#  512486431,
#  512486458,
#  512486671,
#  512486709,
#  512486788,
#  512487102,
#  512487622,
#  512487917,
#  512488081,
#  512488159,
#  512488220,
#  512488240,
#  512488242,
#  512488259,
#  512488260,
#  512488473,
#  512488639,
#  512488700,
#  512489153,
#  512489226,
#  512489700,
#  512489956,
#  512490560,
#  512490712,
#  512490920,
#  512491210,
#  512491350,
#  512491855,
#  512492351,
#  512492498,
#  512492754,
#  512493131,
#  512493947,
#  512494315,
#  512494522,
#  512494596,
#  512494782,
#  512495159,
#  512495214,
#  512495733,
#  512496136,
#  512496255,
#  512496336,
#  512496901,
#  512497237,
#  512497275,
#  512497340,
#  512497573,
#  512498135,
#  512498202,
#  512499059,
#  512499205,
#  512499838,
#  512500060,
#  512500515,
#  512500784,
#  512500808,
#  512500813,
#  512500872,
#  512501209,
#  512501392,
#  512501595,
#  512501604,
#  512501730,
#  512501813,
#  512501897,
#  512502048,
#  512502312,
#  512502328,
#  512502455,
#  512502548,
#  512502580,
#  512502585,
#  512502818,
#  512502837,
#  512503217,
#  512503371,
#  512503573,
#  512504673,
#  512504727,
#  512504806,
#  512504879,
#  512504927,
#  512505145,
#  512505295,
#  512505625,
#  512505637,
#  512505919,
#  512505943,
#  512506368,
#  512506407,
#  512506495,
#  512506638,
#  512506774,
#  512507552,
#  512507779,
#  512507787,
#  512507908,
#  512507915,
#  512507952,
#  512508337,
#  512508537,
#  512508722,
#  512508761,
#  512508805,
#  512509557,
#  512509713,
#  512509763,
#  512509843,
#  512509844,
#  512510040,
#  512510124,
#  512510652,
#  512510936,
#  512510976,
#  512511056,
#  512511109,
#  512511204,
#  512511768,
#  512512058,
#  512512351,
#  512512753,
#  512512789,
#  512513033,
#  512513103,
#  512513394,
#  512513760,
#  512514137,
#  512514709,
#  512514811,
#  512514945,
#  512515249,
#  512515937,
#  512516182,
#  512516593,
#  512516934,
#  512517383,
#  512517779,
#  512517890,
#  512518354,
#  512518372,
#  512518423,
#  512518992,
#  512519384,
#  512519406,
#  512519699,
#  512519752,
#  512520050,
#  512520547,
#  512520626,
#  512521088,
#  512521427,
#  512521554,
#  512521657,
#  512521664,
#  512522224,
#  512522297,
#  512522408,
#  512522460,
#  512522609,
#  512522682,
#  512523276,
#  512523447,
#  512523998,
#  512524031,
#  512524188,
#  512524262,
#  512524395,
#  512524487,
#  512524826,
#  512525167,
#  512525605,
#  512525789,
#  512526098,
#  512526177,
#  512526460,
#  512527073,
#  512527239,
#  512527247,
#  512527258,
#  512527392,
#  512527421,
#  512527815,
#  512528170,
#  512528314,
#  512528669,
#  512528795,
#  512529043,
#  512529258,
#  512529429,
#  512529737,
#  512529795,
#  512530231,
#  512530235,
#  512530436,
#  512530510,
#  512530637,
#  512530696,
#  512530851,
#  512530972,
#  512531284,
#  512531369,
#  512531736,
#  512531751,
#  512531824,
#  512531874,
#  512531881,
#  512531910,
#  512531993,
#  512532035,
#  512532222,
#  512532293,
#  512532468,
#  512532480,
#  512532861,
#  512532949,
#  512533329,
#  512533522,
#  512534021,
#  512534042,
#  512534369,
#  512534489,
#  512534598,
#  512534959,
#  512535515,
#  512535542,
#  512535721,
#  512536146,
#  512536503,
#  512536513,
#  512536608,
#  512536719,
#  512536743,
#  512536746,
#  512536924,
#  512537429,
#  512537692,
#  512537754,
#  512537861,
#  512538113,
#  512538386,
#  512538720,
#  512539354,
#  512539558,
#  512539956,
#  512539986,
#  512540123,
#  512540286,
#  512540417,
#  512540816,
#  512540874,
#  512541320,
#  512541542,
#  512541669,
#  512541859,
#  512542016,
#  512542036,
#  512542095,
#  512542311,
#  512542561,
#  512542676,
#  512542830,
#  512542924,
#  512543641,
#  512543699,
#  512543905,
#  512543917,
#  512544107,
#  512544311,
#  512544376,
#  512544500,
#  512544559,
#  512544663,
#  512544718,
#  512544746,
#  512544973,
#  512545043,
#  512545050,
#  512546111,
#  512546149,
#  512546417,
#  512546633,
#  512546634,
#  512546667,
#  512546820,
#  512546912,
#  512546972,
#  512547020,
#  512547745,
#  512548048,
#  512548216,
#  512548439,
#  512548441,
#  512548657,
#  512548668,
#  512548681,
#  512548793,
#  512548997,
#  512549027,
#  512549122,
#  512549456,
#  512549485,
#  512549513,
#  512549593,
#  512549850,
#  512549890,
#  512549891,
#  512549940,
#  512550016,
#  512550264,
#  512550859,
#  512550960,
#  512551009,
#  512551688,
#  512551804,
#  512552085,
#  512553513,
#  512553779,
#  512553949,
#  512554359,
#  512554477,
#  512554567,
#  512554581,
#  512555237,
#  512555634,
#  512555645,
#  512555726,
#  512556230,
#  512556394,
#  512556582,
#  512556627,
#  512556832,
#  512556968,
#  512557446,
#  512557689,
#  512557746,
#  512557752,
#  512557934,
#  512558126,
#  512558226,
#  512558427,
#  512558789,
#  512558940,
#  512558985,
#  512559024,
#  512559065,
#  512559421,
#  512559748,
#  512559912,
#  512560143,
#  512560158,
#  512560255,
#  512560435,
#  512560766,
#  512560964,
#  512561457,
#  512561550,
#  512561681,
#  512562708,
#  512562743,
#  512562872,
#  512563078,
#  512563543,
#  512564147,
#  512564629,
#  512565024,
#  512565266,
#  512565346,
#  512565494,
#  512565604,
#  512565903,
#  ...]

# %%
df_user0 = total[(total['event_type'] == 'purchase') & (total['user_id'].isin(idx0))]
df_user0
# Out:
#                        event_time event_type  product_id  \
# 7       2019-10-16 12:04:38+00:00   purchase     3601438
# 333     2019-10-16 12:04:54+00:00   purchase     5100562
# 1551    2019-10-16 12:05:54+00:00   purchase     2800590
# 3398    2019-10-16 12:07:27+00:00   purchase     3701428
# 5151    2019-10-16 12:08:50+00:00   purchase     1004870
# ...                           ...        ...         ...
# 7053676 2019-10-11 17:40:01+00:00   purchase    13901530
# 7053893 2019-10-11 17:40:11+00:00   purchase     1004776
# 7061563 2019-10-11 17:45:38+00:00   purchase     4802401
# 7065813 2019-10-11 17:48:33+00:00   purchase     4804056
# 7070638 2019-10-11 17:51:48+00:00   purchase     5100551
#
#                             category_code     brand       price    user_id
# 7               appliances.kitchen.washer      beko  203.410004  512935426
# 333                    electronics.clocks     apple  295.750000  512938489
# 1551     appliances.kitchen.refrigerators  dauscher  334.369995  548085506
# 3398        appliances.environment.vacuum    arnica   69.239998  532727338
# 5151               electronics.smartphone   samsung  287.649994  514669514
# ...                                   ...       ...         ...        ...
# 7053676    construction.components.faucet     grohe  101.199997  518110521
# 7053893            electronics.smartphone    xiaomi  183.270004  525086132
# 7061563       electronics.audio.headphone   samsung   43.860001  515986744
# 7065813       electronics.audio.headphone     apple  160.880005  515986744
# 7070638                electronics.clocks    xiaomi  167.289993  551491743
#
# [75047 rows x 7 columns]

# %%
df_user0['brand'].value_counts(1).head(10).plot.bar(rot=0)
# Out:
# <Axes: >

# %%
df_user0['category_code'].value_counts(1).head(10).plot.barh(rot=0)
# Out:
# <Axes: >

# %% [markdown]
# #### 1번 집단

# %%
clu1 = df[df['Cluster'] == 1]
clu1
# Out:
#            Recency  Frequency  MonetaryValue  R  F  M RFM_segment  RFM_score  \
# user_id
# 384989212       14          1      41.439999  3  1  1         311          5
# 401021311       11          1     231.639999  3  1  3         313          7
# 424869855        8          1      88.290001  4  1  1         411          6
# 431246706        9          1     170.830002  4  1  2         412          7
# 433754231       30          1     321.730011  1  1  3         113          5
# ...            ...        ...            ... .. .. ..         ...        ...
# 564800747        5          1      12.840000  4  4  1         441          9
# 564853008        4          1       8.730000  5  4  1         541         10
# 564928973        4          1       7.930000  5  4  1         541         10
# 565120631        4          1       8.490000  5  4  1         541         10
# 565145728        4          1       6.670000  5  4  1         541         10
#
#           RFM_class  Cluster
# user_id
# 384989212    silver        1
# 401021311    silver        1
# 424869855    silver        1
# 431246706    silver        1
# 433754231    silver        1
# ...             ...      ...
# 564800747      gold        1
# 564853008      gold        1
# 564928973      gold        1
# 565120631      gold        1
# 565145728      gold        1
#
# [82882 rows x 10 columns]

# %%
clu1['RFM_class'].value_counts(1).plot.bar(rot=0) # 0번 클러스터에는 sliver 고객이 많음
# Out:
# <Axes: >

# %%
clu1 = clu1.reset_index()
clu1
# Out:
#          user_id  Recency  Frequency  MonetaryValue  R  F  M RFM_segment  \
# 0      384989212       14          1      41.439999  3  1  1         311
# 1      401021311       11          1     231.639999  3  1  3         313
# 2      424869855        8          1      88.290001  4  1  1         411
# 3      431246706        9          1     170.830002  4  1  2         412
# 4      433754231       30          1     321.730011  1  1  3         113
# ...          ...      ...        ...            ... .. .. ..         ...
# 82877  564800747        5          1      12.840000  4  4  1         441
# 82878  564853008        4          1       8.730000  5  4  1         541
# 82879  564928973        4          1       7.930000  5  4  1         541
# 82880  565120631        4          1       8.490000  5  4  1         541
# 82881  565145728        4          1       6.670000  5  4  1         541
#
#        RFM_score RFM_class  Cluster
# 0              5    silver        1
# 1              7    silver        1
# 2              6    silver        1
# 3              7    silver        1
# 4              5    silver        1
# ...          ...       ...      ...
# 82877          9      gold        1
# 82878         10      gold        1
# 82879         10      gold        1
# 82880         10      gold        1
# 82881         10      gold        1
#
# [82882 rows x 11 columns]

# %%
idx1 = clu1['user_id'].to_list()
idx1
# Out:
# [384989212,
#  401021311,
#  424869855,
#  431246706,
#  433754231,
#  438992161,
#  440471930,
#  440756116,
#  441522689,
#  446080337,
#  450756413,
#  454108351,
#  457360398,
#  462288298,
#  462757549,
#  467449679,
#  467920571,
#  470561711,
#  470964674,
#  473668240,
#  477122297,
#  477366703,
#  477652311,
#  477733329,
#  477974596,
#  480721150,
#  481640416,
#  482482539,
#  485289776,
#  485909616,
#  486212808,
#  488379220,
#  488476721,
#  488925088,
#  489171912,
#  491026745,
#  492234274,
#  493591413,
#  494841527,
#  495766314,
#  496157842,
#  497552274,
#  498360472,
#  499538223,
#  499668583,
#  499864844,
#  500007005,
#  501772199,
#  502364367,
#  502403976,
#  503684910,
#  504064036,
#  504429960,
#  505073581,
#  505899545,
#  506551375,
#  509208358,
#  510344108,
#  510514633,
#  510780164,
#  512363639,
#  512363656,
#  512363693,
#  512363742,
#  512363812,
#  512363853,
#  512363898,
#  512363901,
#  512363947,
#  512363994,
#  512364002,
#  512364022,
#  512364033,
#  512364192,
#  512364336,
#  512364387,
#  512364422,
#  512364480,
#  512364515,
#  512364526,
#  512364595,
#  512364715,
#  512364719,
#  512364745,
#  512364746,
#  512364992,
#  512365063,
#  512365189,
#  512365334,
#  512365338,
#  512365511,
#  512365521,
#  512365536,
#  512365581,
#  512365686,
#  512365732,
#  512365904,
#  512366080,
#  512366169,
#  512366272,
#  512366274,
#  512366339,
#  512366424,
#  512366512,
#  512366600,
#  512366772,
#  512366835,
#  512366912,
#  512366966,
#  512367025,
#  512367128,
#  512367267,
#  512367362,
#  512367396,
#  512367400,
#  512367501,
#  512367522,
#  512367528,
#  512367534,
#  512367576,
#  512367668,
#  512367789,
#  512367811,
#  512367865,
#  512367911,
#  512367956,
#  512368047,
#  512368269,
#  512368285,
#  512368333,
#  512368347,
#  512368376,
#  512368578,
#  512368680,
#  512368705,
#  512368948,
#  512369219,
#  512369436,
#  512369456,
#  512369920,
#  512369958,
#  512370084,
#  512370123,
#  512370237,
#  512370287,
#  512370349,
#  512370388,
#  512370533,
#  512370841,
#  512370859,
#  512370865,
#  512371009,
#  512371020,
#  512371195,
#  512371403,
#  512371473,
#  512371625,
#  512371680,
#  512371794,
#  512371976,
#  512372105,
#  512372255,
#  512372546,
#  512372550,
#  512372678,
#  512372829,
#  512372900,
#  512373029,
#  512373050,
#  512373142,
#  512373231,
#  512373434,
#  512373557,
#  512373688,
#  512373776,
#  512373817,
#  512373871,
#  512373885,
#  512374431,
#  512374432,
#  512374786,
#  512374931,
#  512374978,
#  512375061,
#  512375117,
#  512375133,
#  512375169,
#  512375263,
#  512375392,
#  512375543,
#  512375545,
#  512375577,
#  512375922,
#  512375948,
#  512376107,
#  512376127,
#  512376202,
#  512376205,
#  512376218,
#  512376343,
#  512376350,
#  512376356,
#  512376473,
#  512376684,
#  512377065,
#  512377185,
#  512377212,
#  512377478,
#  512377570,
#  512377599,
#  512377619,
#  512377623,
#  512377624,
#  512377648,
#  512377790,
#  512377991,
#  512377994,
#  512378203,
#  512378343,
#  512378369,
#  512378389,
#  512378423,
#  512378495,
#  512378861,
#  512378897,
#  512379002,
#  512379213,
#  512379387,
#  512379450,
#  512379544,
#  512379569,
#  512379632,
#  512379704,
#  512379852,
#  512379859,
#  512379862,
#  512379945,
#  512379953,
#  512379960,
#  512380003,
#  512380025,
#  512380051,
#  512380161,
#  512380417,
#  512380500,
#  512380661,
#  512380688,
#  512380721,
#  512380791,
#  512380899,
#  512380904,
#  512381021,
#  512381027,
#  512381050,
#  512381250,
#  512381347,
#  512381348,
#  512381538,
#  512381854,
#  512382242,
#  512382296,
#  512382441,
#  512382571,
#  512382582,
#  512382589,
#  512382758,
#  512382768,
#  512382832,
#  512382851,
#  512382985,
#  512383185,
#  512383276,
#  512383317,
#  512383347,
#  512383515,
#  512383542,
#  512383584,
#  512383679,
#  512383788,
#  512383805,
#  512383818,
#  512383836,
#  512383960,
#  512384407,
#  512384435,
#  512384532,
#  512384550,
#  512384661,
#  512384967,
#  512384976,
#  512385001,
#  512385140,
#  512385152,
#  512385201,
#  512385231,
#  512385273,
#  512385794,
#  512385859,
#  512385872,
#  512385873,
#  512385955,
#  512385957,
#  512386048,
#  512386143,
#  512386240,
#  512386300,
#  512386325,
#  512386327,
#  512386351,
#  512386394,
#  512386517,
#  512386672,
#  512386770,
#  512386857,
#  512387030,
#  512387081,
#  512387143,
#  512387171,
#  512387309,
#  512387331,
#  512387366,
#  512387493,
#  512387569,
#  512387796,
#  512387878,
#  512388051,
#  512388160,
#  512388244,
#  512388347,
#  512388375,
#  512388648,
#  512388734,
#  512388808,
#  512389101,
#  512389345,
#  512389738,
#  512389812,
#  512389859,
#  512389960,
#  512390001,
#  512390035,
#  512390077,
#  512390221,
#  512390256,
#  512390516,
#  512390525,
#  512390673,
#  512390973,
#  512391011,
#  512391098,
#  512391274,
#  512391306,
#  512391392,
#  512391514,
#  512391583,
#  512391773,
#  512391935,
#  512392104,
#  512392232,
#  512392278,
#  512392316,
#  512392338,
#  512392348,
#  512392370,
#  512392382,
#  512392422,
#  512392441,
#  512392483,
#  512392484,
#  512392493,
#  512392571,
#  512392585,
#  512392658,
#  512392712,
#  512393153,
#  512393187,
#  512393191,
#  512393210,
#  512393249,
#  512393292,
#  512393311,
#  512393346,
#  512393368,
#  512393380,
#  512393732,
#  512393921,
#  512393999,
#  512394244,
#  512394249,
#  512394611,
#  512394838,
#  512394916,
#  512394917,
#  512394944,
#  512395174,
#  512395229,
#  512395368,
#  512395502,
#  512395530,
#  512395614,
#  512395692,
#  512395696,
#  512395823,
#  512395946,
#  512396209,
#  512396251,
#  512396415,
#  512396559,
#  512396583,
#  512396628,
#  512396672,
#  512396760,
#  512396957,
#  512397473,
#  512397485,
#  512397505,
#  512397533,
#  512397537,
#  512397607,
#  512397707,
#  512397718,
#  512397764,
#  512397800,
#  512397916,
#  512398120,
#  512398572,
#  512398680,
#  512398717,
#  512398823,
#  512398851,
#  512398887,
#  512399142,
#  512399322,
#  512399446,
#  512399465,
#  512399991,
#  512400386,
#  512400559,
#  512400624,
#  512400644,
#  512400731,
#  512400789,
#  512400853,
#  512400872,
#  512401002,
#  512401060,
#  512401539,
#  512401551,
#  512401643,
#  512401647,
#  512401673,
#  512401698,
#  512401789,
#  512401803,
#  512401864,
#  512401991,
#  512402558,
#  512402596,
#  512402661,
#  512402740,
#  512402843,
#  512402901,
#  512402944,
#  512402987,
#  512403573,
#  512403722,
#  512404007,
#  512404267,
#  512404302,
#  512404592,
#  512404619,
#  512404695,
#  512404929,
#  512405445,
#  512405801,
#  512405879,
#  512406201,
#  512406334,
#  512406364,
#  512406402,
#  512406588,
#  512406886,
#  512406945,
#  512407347,
#  512407810,
#  512407900,
#  512407916,
#  512408376,
#  512408914,
#  512409058,
#  512409199,
#  512409208,
#  512409328,
#  512409555,
#  512409593,
#  512409674,
#  512410077,
#  512410102,
#  512410187,
#  512410203,
#  512410249,
#  512410254,
#  512410318,
#  512410335,
#  512410415,
#  512410535,
#  512410665,
#  512410719,
#  512410912,
#  512411049,
#  512411169,
#  512411193,
#  512411254,
#  512411304,
#  512411482,
#  512411616,
#  512411670,
#  512411694,
#  512411809,
#  512411923,
#  512412030,
#  512412060,
#  512412072,
#  512412247,
#  512412273,
#  512412326,
#  512412357,
#  512412404,
#  512412945,
#  512413206,
#  512413348,
#  512413496,
#  512413580,
#  512413902,
#  512414065,
#  512414611,
#  512414672,
#  512414782,
#  512414821,
#  512415080,
#  512415312,
#  512415334,
#  512415338,
#  512415442,
#  512415491,
#  512415512,
#  512415625,
#  512415703,
#  512416056,
#  512416118,
#  512416226,
#  512416527,
#  512416613,
#  512416678,
#  512416681,
#  512416785,
#  512417005,
#  512417322,
#  512417922,
#  512418072,
#  512418196,
#  512418246,
#  512418306,
#  512418512,
#  512418663,
#  512418754,
#  512418949,
#  512419026,
#  512419047,
#  512419104,
#  512419298,
#  512419367,
#  512419879,
#  512420064,
#  512420169,
#  512420345,
#  512420429,
#  512420560,
#  512420572,
#  512420588,
#  512420661,
#  512420772,
#  512421206,
#  512421414,
#  512421573,
#  512421583,
#  512421711,
#  512421751,
#  512421900,
#  512421902,
#  512421992,
#  512422200,
#  512422293,
#  512422343,
#  512422395,
#  512422429,
#  512422485,
#  512422640,
#  512422698,
#  512422740,
#  512423146,
#  512423205,
#  512423466,
#  512423522,
#  512423600,
#  512423822,
#  512424001,
#  512424076,
#  512424109,
#  512424366,
#  512424827,
#  512424894,
#  512424948,
#  512425096,
#  512425105,
#  512425127,
#  512425180,
#  512425184,
#  512425192,
#  512425298,
#  512425634,
#  512425801,
#  512426131,
#  512426202,
#  512426335,
#  512426553,
#  512426637,
#  512426677,
#  512426738,
#  512426858,
#  512426864,
#  512427072,
#  512427112,
#  512427243,
#  512427263,
#  512427300,
#  512427322,
#  512427433,
#  512427484,
#  512427962,
#  512428497,
#  512428501,
#  512428570,
#  512428682,
#  512428707,
#  512428761,
#  512428895,
#  512429134,
#  512429418,
#  512429606,
#  512429772,
#  512430210,
#  512430255,
#  512430293,
#  512430447,
#  512430531,
#  512430537,
#  512430766,
#  512430793,
#  512430839,
#  512430889,
#  512430908,
#  512431581,
#  512431705,
#  512431863,
#  512431973,
#  512432515,
#  512432726,
#  512432930,
#  512433172,
#  512433264,
#  512433328,
#  512433437,
#  512433553,
#  512433656,
#  512434022,
#  512434074,
#  512434100,
#  512434121,
#  512434426,
#  512434600,
#  512434641,
#  512434769,
#  512434898,
#  512435113,
#  512435448,
#  512435477,
#  512435480,
#  512435519,
#  512435622,
#  512435646,
#  512435742,
#  512435814,
#  512435820,
#  512436144,
#  512436785,
#  512436809,
#  512437001,
#  512437328,
#  512437531,
#  512437625,
#  512437742,
#  512437785,
#  512437929,
#  512437998,
#  512438165,
#  512438300,
#  512438370,
#  512438548,
#  512438616,
#  512438744,
#  512438820,
#  512438957,
#  512438972,
#  512439068,
#  512439215,
#  512439369,
#  512439410,
#  512439627,
#  512439739,
#  512439767,
#  512439824,
#  512439828,
#  512439846,
#  512440081,
#  512440115,
#  512440574,
#  512440627,
#  512440670,
#  512440868,
#  512440956,
#  512441252,
#  512441287,
#  512441322,
#  512441349,
#  512441407,
#  512441901,
#  512441949,
#  512441994,
#  512442057,
#  512442313,
#  512442511,
#  512442608,
#  512442694,
#  512442701,
#  512442777,
#  512443007,
#  512443025,
#  512443240,
#  512443759,
#  512443780,
#  512443815,
#  512443842,
#  512444155,
#  512444367,
#  512444423,
#  512444621,
#  512444876,
#  512445110,
#  512445125,
#  512445164,
#  512445359,
#  512445610,
#  512445820,
#  512445828,
#  512445944,
#  512446017,
#  512446128,
#  512446144,
#  512446185,
#  512446324,
#  512446605,
#  512446607,
#  512446686,
#  512446893,
#  512446914,
#  512447162,
#  512447399,
#  512447423,
#  512447451,
#  512447564,
#  512447950,
#  512448158,
#  512448459,
#  512448573,
#  512448836,
#  512448843,
#  512449111,
#  512449218,
#  512449303,
#  512449365,
#  512449387,
#  512449446,
#  512449511,
#  512449658,
#  512449731,
#  512449747,
#  512449761,
#  512449833,
#  512449936,
#  512450047,
#  512450146,
#  512450931,
#  512451133,
#  512451362,
#  512451556,
#  512451621,
#  512451655,
#  512451783,
#  512451896,
#  512451917,
#  512451952,
#  512452241,
#  512452327,
#  512452342,
#  512452496,
#  512452497,
#  512452605,
#  512452768,
#  512452935,
#  512452976,
#  512453055,
#  512453372,
#  512453424,
#  512453667,
#  512453794,
#  512454070,
#  512454189,
#  512454688,
#  512454751,
#  512455020,
#  512455175,
#  512455504,
#  512455540,
#  512455563,
#  512455819,
#  512455885,
#  512455899,
#  512455963,
#  512456163,
#  512456209,
#  512456277,
#  512456312,
#  512456398,
#  512457202,
#  512457397,
#  512457477,
#  512457533,
#  512457653,
#  512457716,
#  512457913,
#  512458252,
#  512458481,
#  512458613,
#  512458726,
#  512458789,
#  512458891,
#  512458900,
#  512459055,
#  512459213,
#  512459214,
#  512459290,
#  512459346,
#  512459467,
#  512459640,
#  512459783,
#  512459829,
#  512460003,
#  512460032,
#  512460338,
#  512460532,
#  512460602,
#  512460611,
#  512460618,
#  512460700,
#  512460917,
#  512461014,
#  512461119,
#  512461167,
#  512461229,
#  512461369,
#  512461543,
#  512461606,
#  512461716,
#  512461748,
#  512461763,
#  512461908,
#  512461937,
#  512461958,
#  512462050,
#  512462072,
#  512462154,
#  512462185,
#  512462228,
#  512462408,
#  512462504,
#  512462670,
#  512462729,
#  512462886,
#  512462926,
#  512463402,
#  512463471,
#  512463541,
#  512463600,
#  512463712,
#  512463829,
#  512463957,
#  512463991,
#  512464027,
#  512464147,
#  512464404,
#  512464644,
#  512464893,
#  512464946,
#  512465037,
#  512465154,
#  512465187,
#  512465307,
#  512465335,
#  512465448,
#  512465465,
#  512465690,
#  512465853,
#  512466073,
#  512466189,
#  512466196,
#  512466201,
#  512466231,
#  512466325,
#  512466342,
#  512466361,
#  512466536,
#  512466618,
#  512466648,
#  512466747,
#  512466794,
#  512466824,
#  512466905,
#  512466963,
#  512466970,
#  512467290,
#  512467550,
#  512467596,
#  512467768,
#  512468087,
#  512468322,
#  512468326,
#  512468343,
#  512469117,
#  512469237,
#  512469260,
#  512469333,
#  512469811,
#  512469998,
#  512470096,
#  512470320,
#  512470332,
#  512470383,
#  512470389,
#  512470491,
#  512470648,
#  512470914,
#  512470925,
#  512471213,
#  512471661,
#  512471676,
#  512471770,
#  512471834,
#  512471889,
#  512472121,
#  512472148,
#  512472313,
#  512472499,
#  512472576,
#  512472594,
#  512472600,
#  512472929,
#  512473126,
#  512473397,
#  512473601,
#  512473685,
#  512474427,
#  512474693,
#  512474712,
#  512474733,
#  512474893,
#  512474896,
#  512475044,
#  512475075,
#  512475267,
#  512475311,
#  512475425,
#  512475431,
#  512475538,
#  512475572,
#  512475770,
#  512475902,
#  512476128,
#  512476146,
#  512476259,
#  ...]

# %%
df_user1 = total[(total['event_type'] == 'purchase') & (total['user_id'].isin(idx1))]
df_user1
# Out:
#                        event_time event_type  product_id  \
# 53      2019-10-16 12:04:39+00:00   purchase     1004750
# 84      2019-10-16 12:04:41+00:00   purchase     1004834
# 406     2019-10-16 12:04:58+00:00   purchase     5100377
# 744     2019-10-16 12:05:15+00:00   purchase     3601405
# 775     2019-10-16 12:05:17+00:00   purchase     3701134
# ...                           ...        ...         ...
# 7072819 2019-10-11 17:53:21+00:00   purchase     4804056
# 7073138 2019-10-11 17:53:37+00:00   purchase     4803653
# 7073793 2019-10-11 17:54:05+00:00   purchase     1004785
# 7073974 2019-10-11 17:54:12+00:00   purchase     1004962
# 7074469 2019-10-11 17:54:34+00:00   purchase     1003235
#
#                          category_code    brand       price    user_id
# 53              electronics.smartphone  samsung  195.619995  560839537
# 84              electronics.smartphone  samsung  173.389999  545171410
# 406                 electronics.clocks   xiaomi   70.529999  560796347
# 744          appliances.kitchen.washer     beko  180.160004  531195883
# 775      appliances.environment.vacuum    bosch  105.279999  523136092
# ...                                ...      ...         ...        ...
# 7072819    electronics.audio.headphone    apple  160.880005  512402901
# 7073138    electronics.audio.headphone   harper   38.330002  536500818
# 7073793         electronics.smartphone   huawei  272.049988  559132868
# 7073974         electronics.smartphone    nokia  128.490005  553843399
# 7074469         electronics.smartphone   huawei  128.419998  559189082
#
# [88248 rows x 7 columns]

# %%
df_user1['brand'].value_counts(1).head(10).plot.bar(rot=0)
# Out:
# <Axes: >

# %%
df_user1['category_code'].value_counts(1).head(10).plot.barh(rot=0)
# Out:
# <Axes: >

# %% [markdown]
# #### 2번 집단

# %%
clu2 = df[df['Cluster'] == 2]
clu2
# Out:
#            Recency  Frequency  MonetaryValue  R  F  M RFM_segment  RFM_score  \
# user_id
# 475786534       23          6    1551.590088  2  5  5         255         12
# 489085769       11          8     897.750000  3  5  4         354         12
# 492103460       24          6    2157.790039  2  5  5         255         12
# 493690536       11          4    1095.280029  3  5  5         355         13
# 497226076        2         14   10488.480469  5  5  5         555         15
# ...            ...        ...            ... .. .. ..         ...        ...
# 566209184        1          3    1597.709961  5  5  5         555         15
# 566213717        1          3    2167.200195  5  5  5         555         15
# 566215463        1          4    1725.520020  5  5  5         555         15
# 566229570        1          4    4509.089844  5  5  5         555         15
# 566233093        1          3    1492.540039  5  5  5         555         15
#
#           RFM_class  Cluster
# user_id
# 475786534  platinum        2
# 489085769  platinum        2
# 492103460  platinum        2
# 493690536  platinum        2
# 497226076  platinum        2
# ...             ...      ...
# 566209184  platinum        2
# 566213717  platinum        2
# 566215463  platinum        2
# 566229570  platinum        2
# 566233093  platinum        2
#
# [23241 rows x 10 columns]

# %%
clu2['RFM_class'].value_counts(1).plot.bar(rot=0) # 2번 클러스터에는 platinum 고객이 많음
# Out:
# <Axes: >

# %%
clu2 = clu2.reset_index()
clu2
# Out:
#          user_id  Recency  Frequency  MonetaryValue  R  F  M RFM_segment  \
# 0      475786534       23          6    1551.590088  2  5  5         255
# 1      489085769       11          8     897.750000  3  5  4         354
# 2      492103460       24          6    2157.790039  2  5  5         255
# 3      493690536       11          4    1095.280029  3  5  5         355
# 4      497226076        2         14   10488.480469  5  5  5         555
# ...          ...      ...        ...            ... .. .. ..         ...
# 23236  566209184        1          3    1597.709961  5  5  5         555
# 23237  566213717        1          3    2167.200195  5  5  5         555
# 23238  566215463        1          4    1725.520020  5  5  5         555
# 23239  566229570        1          4    4509.089844  5  5  5         555
# 23240  566233093        1          3    1492.540039  5  5  5         555
#
#        RFM_score RFM_class  Cluster
# 0             12  platinum        2
# 1             12  platinum        2
# 2             12  platinum        2
# 3             13  platinum        2
# 4             15  platinum        2
# ...          ...       ...      ...
# 23236         15  platinum        2
# 23237         15  platinum        2
# 23238         15  platinum        2
# 23239         15  platinum        2
# 23240         15  platinum        2
#
# [23241 rows x 11 columns]

# %%
idx2 = clu2['user_id'].to_list()
idx2
# Out:
# [475786534,
#  489085769,
#  492103460,
#  493690536,
#  497226076,
#  512363815,
#  512363879,
#  512363973,
#  512364293,
#  512364323,
#  512364709,
#  512364788,
#  512365112,
#  512365119,
#  512365641,
#  512365722,
#  512366270,
#  512366378,
#  512367004,
#  512367296,
#  512367531,
#  512368226,
#  512368363,
#  512368490,
#  512368678,
#  512368869,
#  512368893,
#  512369042,
#  512369785,
#  512369878,
#  512369885,
#  512370018,
#  512370073,
#  512370162,
#  512370169,
#  512370660,
#  512370917,
#  512371090,
#  512371555,
#  512371970,
#  512372149,
#  512372215,
#  512372217,
#  512372445,
#  512372458,
#  512372673,
#  512372774,
#  512372979,
#  512373203,
#  512373343,
#  512373516,
#  512373717,
#  512373849,
#  512374312,
#  512374410,
#  512374518,
#  512375027,
#  512375076,
#  512375395,
#  512375946,
#  512376264,
#  512376604,
#  512377679,
#  512378417,
#  512379753,
#  512380275,
#  512380379,
#  512380592,
#  512381074,
#  512381263,
#  512381662,
#  512381914,
#  512382386,
#  512382443,
#  512382536,
#  512382778,
#  512382879,
#  512384292,
#  512384358,
#  512384376,
#  512384561,
#  512384653,
#  512384696,
#  512384724,
#  512384747,
#  512384831,
#  512386086,
#  512386210,
#  512386548,
#  512386756,
#  512387554,
#  512387881,
#  512388109,
#  512388376,
#  512388596,
#  512389045,
#  512389127,
#  512389146,
#  512389335,
#  512389344,
#  512389601,
#  512389618,
#  512390049,
#  512390381,
#  512390603,
#  512391736,
#  512392050,
#  512392115,
#  512392349,
#  512392592,
#  512393076,
#  512393285,
#  512393542,
#  512393696,
#  512393742,
#  512393868,
#  512394153,
#  512394753,
#  512394806,
#  512394813,
#  512395561,
#  512396365,
#  512396712,
#  512396840,
#  512396972,
#  512397411,
#  512397595,
#  512398233,
#  512398611,
#  512398866,
#  512398908,
#  512400636,
#  512400833,
#  512400985,
#  512401267,
#  512401354,
#  512402349,
#  512402604,
#  512402632,
#  512402884,
#  512403241,
#  512403757,
#  512403897,
#  512404248,
#  512404506,
#  512404607,
#  512404970,
#  512405369,
#  512405571,
#  512406213,
#  512406376,
#  512406792,
#  512406956,
#  512407440,
#  512407534,
#  512407611,
#  512407895,
#  512408222,
#  512408652,
#  512408968,
#  512409624,
#  512410265,
#  512410396,
#  512410689,
#  512410787,
#  512411038,
#  512411061,
#  512411441,
#  512411678,
#  512411704,
#  512412037,
#  512412340,
#  512412385,
#  512412511,
#  512413306,
#  512413617,
#  512413933,
#  512414373,
#  512414586,
#  512414593,
#  512414733,
#  512415231,
#  512415830,
#  512416095,
#  512416165,
#  512416265,
#  512416391,
#  512416542,
#  512416680,
#  512417147,
#  512417206,
#  512417376,
#  512417696,
#  512417792,
#  512418667,
#  512419000,
#  512419036,
#  512419426,
#  512419524,
#  512419726,
#  512420242,
#  512420258,
#  512420304,
#  512420733,
#  512421126,
#  512421134,
#  512422560,
#  512422583,
#  512422866,
#  512422880,
#  512423854,
#  512423867,
#  512423872,
#  512424171,
#  512424209,
#  512424256,
#  512424424,
#  512424511,
#  512425067,
#  512425205,
#  512425398,
#  512425603,
#  512426001,
#  512426430,
#  512427023,
#  512427115,
#  512427309,
#  512427335,
#  512427417,
#  512427685,
#  512427856,
#  512428581,
#  512428676,
#  512429451,
#  512429610,
#  512430073,
#  512431920,
#  512432163,
#  512432406,
#  512432442,
#  512432509,
#  512432519,
#  512432743,
#  512433381,
#  512433941,
#  512434009,
#  512434544,
#  512434750,
#  512434852,
#  512434925,
#  512435003,
#  512435312,
#  512435438,
#  512435467,
#  512435762,
#  512435975,
#  512436165,
#  512436336,
#  512436344,
#  512436625,
#  512437275,
#  512437594,
#  512437914,
#  512438845,
#  512438848,
#  512438969,
#  512439925,
#  512440152,
#  512440362,
#  512440370,
#  512440814,
#  512440901,
#  512441123,
#  512442194,
#  512442232,
#  512442280,
#  512442409,
#  512442625,
#  512443301,
#  512444189,
#  512444599,
#  512444935,
#  512445284,
#  512445529,
#  512445719,
#  512446281,
#  512446617,
#  512447778,
#  512447973,
#  512448281,
#  512448958,
#  512449156,
#  512449180,
#  512449423,
#  512449452,
#  512449971,
#  512450044,
#  512450593,
#  512450874,
#  512451254,
#  512451507,
#  512451592,
#  512451854,
#  512452237,
#  512452340,
#  512452391,
#  512452414,
#  512452468,
#  512452645,
#  512452885,
#  512452968,
#  512454459,
#  512455617,
#  512456323,
#  512456775,
#  512456961,
#  512457495,
#  512457788,
#  512458411,
#  512459353,
#  512459539,
#  512460204,
#  512460426,
#  512460864,
#  512461237,
#  512461511,
#  512461516,
#  512462447,
#  512463043,
#  512463592,
#  512463653,
#  512463942,
#  512463967,
#  512464252,
#  512464473,
#  512464660,
#  512464702,
#  512465090,
#  512465164,
#  512465881,
#  512466039,
#  512466047,
#  512466748,
#  512466913,
#  512467084,
#  512467267,
#  512469170,
#  512469437,
#  512469838,
#  512470083,
#  512470233,
#  512470304,
#  512470550,
#  512470588,
#  512471062,
#  512471329,
#  512471414,
#  512471454,
#  512471531,
#  512471554,
#  512471585,
#  512471588,
#  512472114,
#  512473172,
#  512473395,
#  512474549,
#  512474589,
#  512474874,
#  512475783,
#  512475860,
#  512476334,
#  512476567,
#  512477329,
#  512477379,
#  512477383,
#  512477990,
#  512478069,
#  512478482,
#  512479014,
#  512479379,
#  512480380,
#  512481982,
#  512482380,
#  512483230,
#  512483413,
#  512483897,
#  512484392,
#  512484704,
#  512484760,
#  512485918,
#  512485976,
#  512486512,
#  512486927,
#  512487065,
#  512487196,
#  512487261,
#  512487625,
#  512487713,
#  512487885,
#  512489331,
#  512489370,
#  512489834,
#  512490497,
#  512490758,
#  512490912,
#  512491275,
#  512491468,
#  512491616,
#  512492384,
#  512492404,
#  512493135,
#  512493561,
#  512493723,
#  512494785,
#  512495256,
#  512495307,
#  512495618,
#  512496159,
#  512498716,
#  512498872,
#  512499295,
#  512499425,
#  512499566,
#  512501103,
#  512501611,
#  512501968,
#  512502146,
#  512502190,
#  512502212,
#  512502450,
#  512502799,
#  512502910,
#  512503114,
#  512503401,
#  512504646,
#  512504770,
#  512505377,
#  512506501,
#  512506589,
#  512506869,
#  512506900,
#  512508879,
#  512509412,
#  512510899,
#  512511019,
#  512511207,
#  512511346,
#  512511358,
#  512511938,
#  512512039,
#  512512379,
#  512512703,
#  512512802,
#  512512996,
#  512513942,
#  512514502,
#  512514956,
#  512515173,
#  512515353,
#  512517150,
#  512517221,
#  512517256,
#  512518212,
#  512518535,
#  512518772,
#  512518856,
#  512520034,
#  512520564,
#  512521102,
#  512521216,
#  512521270,
#  512521314,
#  512521729,
#  512521807,
#  512522487,
#  512523597,
#  512524156,
#  512524833,
#  512524843,
#  512525172,
#  512525276,
#  512525656,
#  512525672,
#  512526019,
#  512526125,
#  512527352,
#  512527768,
#  512529030,
#  512529570,
#  512530450,
#  512530773,
#  512531419,
#  512531501,
#  512532457,
#  512532968,
#  512533044,
#  512533391,
#  512533408,
#  512533846,
#  512534049,
#  512534072,
#  512534259,
#  512534656,
#  512534791,
#  512534928,
#  512536887,
#  512538316,
#  512538576,
#  512538666,
#  512538884,
#  512539881,
#  512541317,
#  512543916,
#  512543923,
#  512545649,
#  512546373,
#  512547126,
#  512547628,
#  512548005,
#  512549291,
#  512550533,
#  512550575,
#  512550629,
#  512550933,
#  512551328,
#  512551344,
#  512551478,
#  512552398,
#  512552476,
#  512552493,
#  512552525,
#  512552527,
#  512552601,
#  512552635,
#  512552667,
#  512552943,
#  512553603,
#  512554052,
#  512554768,
#  512555050,
#  512555808,
#  512556152,
#  512556684,
#  512556904,
#  512557736,
#  512558706,
#  512559080,
#  512560103,
#  512560473,
#  512560701,
#  512561267,
#  512561529,
#  512562157,
#  512562627,
#  512563055,
#  512564251,
#  512564712,
#  512565136,
#  512565174,
#  512565802,
#  512566554,
#  512566627,
#  512567193,
#  512567557,
#  512567671,
#  512567769,
#  512568434,
#  512568544,
#  512568669,
#  512569455,
#  512570194,
#  512570718,
#  512571278,
#  512572086,
#  512572439,
#  512572497,
#  512573765,
#  512574219,
#  512574271,
#  512574500,
#  512574597,
#  512575501,
#  512575526,
#  512575707,
#  512577046,
#  512577074,
#  512577093,
#  512577370,
#  512577810,
#  512577932,
#  512578293,
#  512579165,
#  512579474,
#  512579739,
#  512579908,
#  512580417,
#  512581344,
#  512584596,
#  512588408,
#  512588424,
#  512588467,
#  512588740,
#  512588899,
#  512589613,
#  512589804,
#  512589865,
#  512589983,
#  512590167,
#  512590816,
#  512590920,
#  512591801,
#  512592316,
#  512592548,
#  512593128,
#  512594078,
#  512594413,
#  512595510,
#  512596226,
#  512596752,
#  512596847,
#  512597292,
#  512597466,
#  512597740,
#  512597782,
#  512597857,
#  512598498,
#  512598583,
#  512598705,
#  512599029,
#  512599092,
#  512600196,
#  512600500,
#  512600632,
#  512600817,
#  512601648,
#  512602573,
#  512602712,
#  512602799,
#  512603183,
#  512603494,
#  512604094,
#  512605715,
#  512606185,
#  512606190,
#  512606476,
#  512607090,
#  512607189,
#  512607231,
#  512607380,
#  512607492,
#  512607906,
#  512608150,
#  512609444,
#  512610490,
#  512610545,
#  512610622,
#  512610750,
#  512610839,
#  512611270,
#  512611635,
#  512612244,
#  512612290,
#  512612474,
#  512612554,
#  512613566,
#  512614442,
#  512615330,
#  512617437,
#  512617841,
#  512617890,
#  512617925,
#  512618288,
#  512618898,
#  512618902,
#  512619349,
#  512619359,
#  512619485,
#  512621372,
#  512622626,
#  512622941,
#  512623264,
#  512623349,
#  512623509,
#  512623558,
#  512623794,
#  512623897,
#  512624551,
#  512625151,
#  512625694,
#  512626150,
#  512626689,
#  512627296,
#  512627440,
#  512627462,
#  512629201,
#  512629726,
#  512630413,
#  512630917,
#  512631788,
#  512631794,
#  512632346,
#  512632756,
#  512635497,
#  512637272,
#  512638902,
#  512638940,
#  512639142,
#  512640008,
#  512640356,
#  512640890,
#  512642007,
#  512642715,
#  512643066,
#  512643707,
#  512644069,
#  512644234,
#  512644276,
#  512645815,
#  512646839,
#  512647422,
#  512647783,
#  512647886,
#  512647908,
#  512648445,
#  512649860,
#  512650254,
#  512650504,
#  512651636,
#  512651701,
#  512652138,
#  512652588,
#  512653067,
#  512653782,
#  512654225,
#  512654599,
#  512654674,
#  512655313,
#  512656347,
#  512656630,
#  512657067,
#  512657316,
#  512659956,
#  512660219,
#  512660691,
#  512660830,
#  512662594,
#  512663972,
#  512664074,
#  512664676,
#  512664753,
#  512668182,
#  512668473,
#  512668894,
#  512668939,
#  512669221,
#  512669403,
#  512670642,
#  512670959,
#  512671252,
#  512673657,
#  512674665,
#  512675154,
#  512675609,
#  512676452,
#  512676460,
#  512677857,
#  512677921,
#  512678019,
#  512678836,
#  512680354,
#  512680629,
#  512681163,
#  512681805,
#  512682355,
#  512682823,
#  512683227,
#  512684227,
#  512685665,
#  512685677,
#  512685837,
#  512687979,
#  512688687,
#  512689146,
#  512689680,
#  512690535,
#  512690858,
#  512690896,
#  512692374,
#  512694342,
#  512694511,
#  512694680,
#  512696080,
#  512696234,
#  512696335,
#  512696481,
#  512696754,
#  512698488,
#  512699085,
#  512699297,
#  512699299,
#  512699422,
#  512699454,
#  512699530,
#  512699779,
#  512700685,
#  512700903,
#  512701215,
#  512701320,
#  512701886,
#  512702505,
#  512702777,
#  512703298,
#  512703327,
#  512703508,
#  512703972,
#  512704796,
#  512704991,
#  512705957,
#  512706311,
#  512706387,
#  512707169,
#  512707474,
#  512707659,
#  512708249,
#  512708516,
#  512708891,
#  512709346,
#  512709490,
#  512709586,
#  512709719,
#  512709792,
#  512710319,
#  512711336,
#  512711408,
#  512711981,
#  512712386,
#  512712514,
#  512712557,
#  512713549,
#  512714138,
#  512714478,
#  512714671,
#  512714978,
#  512715060,
#  512715329,
#  512715529,
#  512715630,
#  512715914,
#  512716289,
#  512716365,
#  512716730,
#  512717028,
#  512717356,
#  512717769,
#  512718404,
#  512719476,
#  512719506,
#  512719597,
#  512720154,
#  512720197,
#  512720461,
#  512720667,
#  512721459,
#  512721548,
#  512721627,
#  512721653,
#  512721703,
#  512722174,
#  512722353,
#  512722943,
#  512722979,
#  512724286,
#  512724696,
#  512724931,
#  512725032,
#  512725353,
#  512725356,
#  512725644,
#  512725821,
#  512726170,
#  512726291,
#  512726656,
#  512726712,
#  512727060,
#  512727239,
#  512728152,
#  512728517,
#  512728536,
#  512728785,
#  512729341,
#  512729384,
#  512729500,
#  512729909,
#  512730041,
#  512730332,
#  512730829,
#  512730977,
#  512731454,
#  512731746,
#  512732166,
#  512732817,
#  512733254,
#  512733627,
#  512733812,
#  512733891,
#  512734912,
#  512735318,
#  512735818,
#  512735874,
#  512736046,
#  512736905,
#  512737133,
#  512738540,
#  512739341,
#  512739346,
#  512739397,
#  512739664,
#  512740298,
#  512740541,
#  512740625,
#  512740816,
#  512740996,
#  512741157,
#  512741596,
#  512741822,
#  512741964,
#  512742411,
#  512742555,
#  512742582,
#  512742719,
#  512743300,
#  512743347,
#  512743358,
#  512744006,
#  512744552,
#  512744832,
#  512745256,
#  512745478,
#  512746189,
#  512746200,
#  512746506,
#  512746975,
#  512747368,
#  512747484,
#  512747556,
#  512747662,
#  512748362,
#  512748489,
#  512748734,
#  512748812,
#  512748834,
#  512748903,
#  512750674,
#  512751255,
#  512751348,
#  512752116,
#  512752270,
#  512752388,
#  512752527,
#  512752769,
#  512752915,
#  512752956,
#  512753208,
#  512753234,
#  512753388,
#  512754161,
#  512754562,
#  512756116,
#  512756913,
#  512757107,
#  512757284,
#  512757372,
#  512757661,
#  512758037,
#  512758602,
#  512758917,
#  512759111,
#  512759604,
#  512759725,
#  512760019,
#  512760277,
#  512760346,
#  512760760,
#  512760937,
#  512762064,
#  512762567,
#  512762590,
#  512762688,
#  512762877,
#  512763314,
#  512763503,
#  512763616,
#  512763671,
#  512763794,
#  512764243,
#  512764348,
#  512764487,
#  512764566,
#  512764574,
#  512765442,
#  ...]

# %%
df_user2 = total[(total['event_type'] == 'purchase') & (total['user_id'].isin(idx2))]
df_user2
# Out:
#                        event_time event_type  product_id  \
# 178     2019-10-16 12:04:46+00:00   purchase     1005105
# 214     2019-10-16 12:04:48+00:00   purchase     1002544
# 295     2019-10-16 12:04:52+00:00   purchase     1003312
# 479     2019-10-16 12:05:03+00:00   purchase     1005135
# 572     2019-10-16 12:05:07+00:00   purchase     1004835
# ...                           ...        ...         ...
# 7072217 2019-10-11 17:52:55+00:00   purchase     3800490
# 7072966 2019-10-11 17:53:28+00:00   purchase     4804055
# 7073479 2019-10-11 17:53:52+00:00   purchase     1003306
# 7073703 2019-10-11 17:54:02+00:00   purchase     1004237
# 7074511 2019-10-11 17:54:36+00:00   purchase     1002524
#
#                        category_code    brand        price    user_id
# 178           electronics.smartphone    apple  1424.209961  514778102
# 214           electronics.smartphone    apple   460.109985  522354527
# 295           electronics.smartphone    apple   699.799988  517222549
# 479           electronics.smartphone    apple  1741.359985  536590960
# 572           electronics.smartphone  samsung   225.190002  517728689
# ...                              ...      ...          ...        ...
# 7072217              appliances.iron  maxwell    15.190000  528301732
# 7072966  electronics.audio.headphone    apple   191.589996  512390049
# 7073479       electronics.smartphone    apple   581.380005  517453153
# 7073703       electronics.smartphone    apple  1085.969971  550623432
# 7074511       electronics.smartphone    apple   566.960022  533409964
#
# [174198 rows x 7 columns]

# %%
df_user2['brand'].value_counts(1).head(10).plot.bar(rot=0)
# Out:
# <Axes: >

# %%
df_user2['category_code'].value_counts(1).head(10).plot.barh(rot=0)
# Out:
# <Axes: >

# %% [markdown]
# #### 3번 집단

# %%
clu3 = df[df['Cluster'] == 3]
clu3
# Out:
#            Recency  Frequency  MonetaryValue  R  F  M RFM_segment  RFM_score  \
# user_id
# 403013066       14          2     807.160034  3  4  4         344         11
# 420935067       25          1     385.839996  2  1  3         213          6
# 435648894       26          1     388.130005  1  1  3         113          5
# 435786120       14          1     437.850006  3  1  4         314          8
# 437371552       30          2     358.289978  1  4  3         143          8
# ...            ...        ...            ... .. .. ..         ...        ...
# 564751628        5          2    1625.109863  4  5  5         455         14
# 564759853        5          2    3326.979980  4  5  5         455         14
# 564791602        5          2    1578.719971  4  5  5         455         14
# 564795691        5          2    2125.570068  4  5  5         455         14
# 564836619        5          2    2725.479980  4  5  5         455         14
#
#           RFM_class  Cluster
# user_id
# 403013066  platinum        3
# 420935067    silver        3
# 435648894    silver        3
# 435786120      gold        3
# 437371552      gold        3
# ...             ...      ...
# 564751628  platinum        3
# 564759853  platinum        3
# 564791602  platinum        3
# 564795691  platinum        3
# 564836619  platinum        3
#
# [66557 rows x 10 columns]

# %%
clu3['RFM_class'].value_counts(1).plot.bar(rot=0) # 3번 클러스터에는 sliver & gold 고객이 많음
# Out:
# <Axes: >

# %%
clu3 = clu3.reset_index()
clu3
# Out:
#          user_id  Recency  Frequency  MonetaryValue  R  F  M RFM_segment  \
# 0      403013066       14          2     807.160034  3  4  4         344
# 1      420935067       25          1     385.839996  2  1  3         213
# 2      435648894       26          1     388.130005  1  1  3         113
# 3      435786120       14          1     437.850006  3  1  4         314
# 4      437371552       30          2     358.289978  1  4  3         143
# ...          ...      ...        ...            ... .. .. ..         ...
# 66552  564751628        5          2    1625.109863  4  5  5         455
# 66553  564759853        5          2    3326.979980  4  5  5         455
# 66554  564791602        5          2    1578.719971  4  5  5         455
# 66555  564795691        5          2    2125.570068  4  5  5         455
# 66556  564836619        5          2    2725.479980  4  5  5         455
#
#        RFM_score RFM_class  Cluster
# 0             11  platinum        3
# 1              6    silver        3
# 2              5    silver        3
# 3              8      gold        3
# 4              8      gold        3
# ...          ...       ...      ...
# 66552         14  platinum        3
# 66553         14  platinum        3
# 66554         14  platinum        3
# 66555         14  platinum        3
# 66556         14  platinum        3
#
# [66557 rows x 11 columns]

# %%
idx3 = clu3['user_id'].to_list()
idx3
# Out:
# [403013066,
#  420935067,
#  435648894,
#  435786120,
#  437371552,
#  444316141,
#  445228646,
#  450275087,
#  454052851,
#  459629038,
#  465723791,
#  466355604,
#  469200473,
#  470193237,
#  474057911,
#  477146770,
#  477493644,
#  478367034,
#  478529085,
#  479752015,
#  479829447,
#  488123390,
#  489320606,
#  490538682,
#  490607253,
#  494312717,
#  495379087,
#  496432902,
#  496605239,
#  496689215,
#  499441861,
#  500246310,
#  502469352,
#  505068510,
#  505337629,
#  506224239,
#  506366879,
#  506796093,
#  508584556,
#  508593823,
#  509369355,
#  509621735,
#  511231471,
#  512363712,
#  512363732,
#  512363769,
#  512363775,
#  512363791,
#  512363931,
#  512363997,
#  512364372,
#  512364557,
#  512364736,
#  512364757,
#  512365193,
#  512365496,
#  512365547,
#  512365577,
#  512365729,
#  512365815,
#  512365864,
#  512366068,
#  512366092,
#  512366455,
#  512366670,
#  512366705,
#  512366827,
#  512366887,
#  512366935,
#  512367099,
#  512367449,
#  512367520,
#  512367876,
#  512367888,
#  512368135,
#  512368168,
#  512368308,
#  512368345,
#  512368789,
#  512368833,
#  512369153,
#  512369242,
#  512369246,
#  512369252,
#  512369324,
#  512369431,
#  512369549,
#  512369703,
#  512369813,
#  512369932,
#  512369962,
#  512369991,
#  512370121,
#  512370239,
#  512370298,
#  512370372,
#  512370396,
#  512370486,
#  512370693,
#  512370698,
#  512370845,
#  512371110,
#  512371297,
#  512371341,
#  512371395,
#  512371411,
#  512371767,
#  512371802,
#  512371824,
#  512371883,
#  512371937,
#  512372185,
#  512372290,
#  512372307,
#  512372342,
#  512372400,
#  512372533,
#  512372651,
#  512372698,
#  512372715,
#  512372746,
#  512373004,
#  512373117,
#  512373454,
#  512373523,
#  512373650,
#  512373833,
#  512373870,
#  512373905,
#  512373946,
#  512374044,
#  512374059,
#  512374165,
#  512374233,
#  512374443,
#  512374444,
#  512374905,
#  512375018,
#  512375019,
#  512375035,
#  512375046,
#  512375245,
#  512375293,
#  512375312,
#  512375657,
#  512375719,
#  512376092,
#  512376105,
#  512376444,
#  512376792,
#  512377238,
#  512377307,
#  512377404,
#  512377694,
#  512377762,
#  512378006,
#  512378015,
#  512378374,
#  512378682,
#  512378762,
#  512378855,
#  512379057,
#  512379118,
#  512379299,
#  512379865,
#  512380035,
#  512380084,
#  512380408,
#  512380460,
#  512380541,
#  512380709,
#  512380727,
#  512380861,
#  512380983,
#  512381328,
#  512381373,
#  512381451,
#  512381948,
#  512382227,
#  512382281,
#  512382614,
#  512382720,
#  512382766,
#  512382808,
#  512382860,
#  512382867,
#  512382995,
#  512383196,
#  512383222,
#  512383224,
#  512383304,
#  512383386,
#  512383648,
#  512383747,
#  512384049,
#  512384303,
#  512384348,
#  512384549,
#  512384925,
#  512385360,
#  512385458,
#  512385556,
#  512385677,
#  512385683,
#  512385832,
#  512386040,
#  512386090,
#  512386104,
#  512386108,
#  512386167,
#  512386474,
#  512386641,
#  512386647,
#  512386898,
#  512386977,
#  512387329,
#  512387336,
#  512387383,
#  512387420,
#  512387463,
#  512387636,
#  512387720,
#  512387962,
#  512388032,
#  512388529,
#  512388532,
#  512388683,
#  512388887,
#  512389015,
#  512389338,
#  512389514,
#  512389540,
#  512389747,
#  512389933,
#  512390054,
#  512390127,
#  512390241,
#  512390296,
#  512390297,
#  512390315,
#  512390372,
#  512390693,
#  512390716,
#  512390816,
#  512391015,
#  512391418,
#  512391703,
#  512391839,
#  512392289,
#  512392586,
#  512392594,
#  512392611,
#  512392733,
#  512392780,
#  512392999,
#  512393004,
#  512393212,
#  512393260,
#  512393396,
#  512393464,
#  512393616,
#  512393909,
#  512393917,
#  512393962,
#  512394035,
#  512394068,
#  512394548,
#  512394614,
#  512394754,
#  512394778,
#  512394823,
#  512394876,
#  512395120,
#  512395354,
#  512395386,
#  512395439,
#  512395747,
#  512395993,
#  512396071,
#  512396110,
#  512396218,
#  512396356,
#  512396363,
#  512396669,
#  512396738,
#  512396845,
#  512396923,
#  512397082,
#  512397090,
#  512397253,
#  512397515,
#  512397594,
#  512398068,
#  512398245,
#  512398588,
#  512399011,
#  512399039,
#  512399120,
#  512399121,
#  512399342,
#  512399346,
#  512399383,
#  512399407,
#  512399481,
#  512399810,
#  512399873,
#  512399877,
#  512399944,
#  512400209,
#  512400273,
#  512400282,
#  512400333,
#  512400576,
#  512400749,
#  512400882,
#  512401046,
#  512401260,
#  512401431,
#  512401571,
#  512401805,
#  512401871,
#  512401909,
#  512402200,
#  512402225,
#  512402370,
#  512402492,
#  512402640,
#  512402926,
#  512402999,
#  512403138,
#  512403401,
#  512403922,
#  512404018,
#  512404171,
#  512404279,
#  512404297,
#  512404459,
#  512404578,
#  512404603,
#  512404809,
#  512405104,
#  512405182,
#  512405233,
#  512405259,
#  512405639,
#  512405706,
#  512406209,
#  512406252,
#  512406463,
#  512406499,
#  512406567,
#  512406572,
#  512406680,
#  512406724,
#  512406732,
#  512406763,
#  512406879,
#  512407037,
#  512407117,
#  512407379,
#  512407417,
#  512407805,
#  512408254,
#  512408260,
#  512408264,
#  512408303,
#  512408595,
#  512408654,
#  512408714,
#  512408783,
#  512408787,
#  512408810,
#  512408878,
#  512408883,
#  512409034,
#  512409100,
#  512409133,
#  512409553,
#  512409837,
#  512409895,
#  512409924,
#  512410097,
#  512410144,
#  512410390,
#  512410522,
#  512410929,
#  512411422,
#  512411717,
#  512411803,
#  512411915,
#  512411920,
#  512412009,
#  512412126,
#  512412240,
#  512412636,
#  512412744,
#  512412965,
#  512413106,
#  512413161,
#  512413418,
#  512413556,
#  512413631,
#  512413668,
#  512413862,
#  512413932,
#  512413957,
#  512414150,
#  512414339,
#  512414510,
#  512414856,
#  512414869,
#  512414907,
#  512415175,
#  512415309,
#  512415506,
#  512415610,
#  512416043,
#  512416120,
#  512416150,
#  512416355,
#  512416425,
#  512416468,
#  512416959,
#  512417061,
#  512417553,
#  512417569,
#  512417593,
#  512417840,
#  512418130,
#  512418151,
#  512418475,
#  512418641,
#  512418689,
#  512418701,
#  512418845,
#  512418890,
#  512418967,
#  512418970,
#  512419196,
#  512419230,
#  512419431,
#  512419489,
#  512419588,
#  512419597,
#  512419672,
#  512419676,
#  512419912,
#  512420142,
#  512420294,
#  512420866,
#  512420869,
#  512420935,
#  512420975,
#  512421171,
#  512421181,
#  512421261,
#  512421320,
#  512421375,
#  512421516,
#  512421536,
#  512421593,
#  512422277,
#  512422525,
#  512422548,
#  512422607,
#  512422999,
#  512423129,
#  512423458,
#  512423477,
#  512423849,
#  512424559,
#  512424655,
#  512424710,
#  512424869,
#  512424950,
#  512425231,
#  512425313,
#  512425970,
#  512426357,
#  512426602,
#  512426820,
#  512426954,
#  512427075,
#  512427268,
#  512427329,
#  512427380,
#  512427407,
#  512427733,
#  512428527,
#  512428763,
#  512428965,
#  512428983,
#  512429073,
#  512429077,
#  512429226,
#  512429516,
#  512429583,
#  512429742,
#  512429826,
#  512429866,
#  512429966,
#  512430141,
#  512430268,
#  512430600,
#  512431018,
#  512431118,
#  512431159,
#  512431219,
#  512431556,
#  512431642,
#  512432492,
#  512432602,
#  512432656,
#  512432705,
#  512433119,
#  512433258,
#  512433568,
#  512433596,
#  512434089,
#  512434716,
#  512434719,
#  512434803,
#  512434820,
#  512434868,
#  512434890,
#  512434953,
#  512434954,
#  512435259,
#  512435432,
#  512435483,
#  512435737,
#  512435822,
#  512435896,
#  512435900,
#  512435944,
#  512435956,
#  512436146,
#  512436177,
#  512436199,
#  512436483,
#  512436533,
#  512436612,
#  512436621,
#  512436661,
#  512436731,
#  512437204,
#  512437392,
#  512437474,
#  512437723,
#  512438173,
#  512438495,
#  512438804,
#  512439020,
#  512439136,
#  512439311,
#  512439708,
#  512439755,
#  512439927,
#  512440296,
#  512440406,
#  512440442,
#  512440638,
#  512440708,
#  512440806,
#  512440842,
#  512441179,
#  512441191,
#  512441416,
#  512441518,
#  512441880,
#  512441948,
#  512441977,
#  512442013,
#  512442050,
#  512442054,
#  512442547,
#  512442796,
#  512442819,
#  512443028,
#  512443039,
#  512443198,
#  512443211,
#  512443327,
#  512443714,
#  512444057,
#  512444084,
#  512444269,
#  512444488,
#  512444665,
#  512444725,
#  512444763,
#  512445009,
#  512445078,
#  512445107,
#  512445325,
#  512445341,
#  512445667,
#  512445852,
#  512446175,
#  512446257,
#  512446854,
#  512447001,
#  512447190,
#  512447512,
#  512447599,
#  512447636,
#  512447652,
#  512447759,
#  512447817,
#  512448182,
#  512448717,
#  512449276,
#  512449463,
#  512449476,
#  512449643,
#  512449735,
#  512450040,
#  512450061,
#  512450077,
#  512450081,
#  512450101,
#  512450105,
#  512450340,
#  512450748,
#  512450989,
#  512451208,
#  512451472,
#  512451482,
#  512451672,
#  512452103,
#  512452585,
#  512452876,
#  512453013,
#  512453117,
#  512453204,
#  512453209,
#  512453358,
#  512453405,
#  512453409,
#  512453659,
#  512453729,
#  512453802,
#  512454316,
#  512454467,
#  512454531,
#  512454647,
#  512454827,
#  512455060,
#  512455089,
#  512455113,
#  512455146,
#  512455177,
#  512455691,
#  512455778,
#  512455893,
#  512455958,
#  512456092,
#  512456181,
#  512456284,
#  512456460,
#  512456525,
#  512456870,
#  512457013,
#  512457150,
#  512457253,
#  512457342,
#  512457504,
#  512457535,
#  512457837,
#  512457895,
#  512457974,
#  512458001,
#  512458083,
#  512458120,
#  512458226,
#  512458235,
#  512458254,
#  512458534,
#  512458714,
#  512459084,
#  512459104,
#  512459247,
#  512459308,
#  512459388,
#  512459495,
#  512459552,
#  512459606,
#  512459731,
#  512459900,
#  512460238,
#  512460253,
#  512460333,
#  512460364,
#  512460472,
#  512460617,
#  512460662,
#  512460856,
#  512460862,
#  512460871,
#  512461036,
#  512461742,
#  512462534,
#  512462656,
#  512462840,
#  512462854,
#  512463129,
#  512463215,
#  512463293,
#  512463930,
#  512464471,
#  512465046,
#  512465189,
#  512465273,
#  512465399,
#  512465586,
#  512465892,
#  512465961,
#  512466129,
#  512466498,
#  512466548,
#  512466939,
#  512467519,
#  512468018,
#  512468361,
#  512468403,
#  512468464,
#  512468739,
#  512468899,
#  512469335,
#  512469420,
#  512469760,
#  512469766,
#  512470325,
#  512470349,
#  512470752,
#  512470884,
#  512471282,
#  512471308,
#  512471569,
#  512471699,
#  512471773,
#  512471975,
#  512472135,
#  512472253,
#  512472650,
#  512473125,
#  512473128,
#  512473187,
#  512473239,
#  512474199,
#  512474425,
#  512474530,
#  512474553,
#  512474615,
#  512474657,
#  512474717,
#  512474752,
#  512475048,
#  512475253,
#  512475575,
#  512475683,
#  512475871,
#  512475972,
#  512475995,
#  512476085,
#  512476255,
#  512476463,
#  512477027,
#  512477428,
#  512477636,
#  512478541,
#  512478551,
#  512478554,
#  512478707,
#  512478862,
#  512479383,
#  512479828,
#  512479992,
#  512480292,
#  512480301,
#  512480341,
#  512480350,
#  512480602,
#  512480682,
#  512480777,
#  512481236,
#  512481279,
#  512481473,
#  512481507,
#  512482011,
#  512482180,
#  512482252,
#  512482501,
#  512482525,
#  512482562,
#  512483064,
#  512483173,
#  512483507,
#  512483681,
#  512483876,
#  512484082,
#  512484159,
#  512484626,
#  512484633,
#  512484649,
#  512484930,
#  512485599,
#  512485685,
#  512485865,
#  512485875,
#  512485980,
#  512486032,
#  512486223,
#  512486350,
#  512487111,
#  512487624,
#  512487648,
#  512487723,
#  512487812,
#  512488020,
#  512488085,
#  512488092,
#  512488164,
#  512489336,
#  512489555,
#  512489892,
#  512489905,
#  512489978,
#  512490181,
#  512490374,
#  512490903,
#  512491001,
#  512491100,
#  512491386,
#  512491771,
#  512492168,
#  512492202,
#  512492343,
#  512492366,
#  512492627,
#  512492774,
#  512493201,
#  512493206,
#  512493295,
#  512493383,
#  512493543,
#  512493967,
#  512493975,
#  512494076,
#  512494248,
#  512494359,
#  512494408,
#  512494462,
#  512494549,
#  512494610,
#  512494669,
#  512494982,
#  512495180,
#  512495260,
#  512495347,
#  512495887,
#  512496144,
#  512496160,
#  512496177,
#  512496193,
#  512496224,
#  512496264,
#  512496629,
#  512496754,
#  512497043,
#  512497226,
#  512497369,
#  512497408,
#  512497534,
#  512497674,
#  512498127,
#  512498385,
#  512498470,
#  512498681,
#  512498725,
#  512499426,
#  512499983,
#  512499993,
#  512500052,
#  512500187,
#  512500412,
#  512500851,
#  512500874,
#  512500911,
#  512500938,
#  512501007,
#  512501315,
#  512501612,
#  512501623,
#  512501684,
#  512501978,
#  512501986,
#  512502090,
#  512502351,
#  512502641,
#  512502710,
#  512503442,
#  512503597,
#  512503652,
#  512503761,
#  512503783,
#  512503804,
#  512503889,
#  512504323,
#  512504876,
#  512505419,
#  512505486,
#  512505504,
#  512505673,
#  512505731,
#  512505995,
#  512506104,
#  512506106,
#  512506177,
#  512506678,
#  512506802,
#  512507649,
#  512507675,
#  512507742,
#  512507939,
#  512508127,
#  512508375,
#  512508710,
#  512509015,
#  512509275,
#  512509388,
#  512509401,
#  512509509,
#  512509539,
#  512509777,
#  512509782,
#  512509925,
#  512510145,
#  512510222,
#  512510286,
#  512510331,
#  512510622,
#  512510627,
#  512510892,
#  512511037,
#  512511129,
#  512511161,
#  512511269,
#  512512122,
#  512512521,
#  512512729,
#  512512816,
#  512513019,
#  512513104,
#  512513296,
#  512513341,
#  512513492,
#  512513772,
#  512513972,
#  512513984,
#  512514291,
#  512514477,
#  512514537,
#  512514646,
#  512515102,
#  512515159,
#  512515208,
#  512515457,
#  512515856,
#  512516069,
#  512516129,
#  512516174,
#  512516793,
#  512517111,
#  512517447,
#  512517464,
#  512517687,
#  512517780,
#  512517886,
#  512517949,
#  512517974,
#  512518127,
#  512518293,
#  512518332,
#  512518589,
#  512518847,
#  512519534,
#  512519943,
#  512519986,
#  512520261,
#  512520365,
#  512520432,
#  512520682,
#  512521162,
#  512521266,
#  512521418,
#  512521511,
#  512521583,
#  512521835,
#  512521992,
#  ...]

# %%
df_user3 = total[(total['event_type'] == 'purchase') & (total['user_id'].isin(idx3))]
df_user3
# Out:
#                        event_time event_type  product_id  \
# 193     2019-10-16 12:04:47+00:00   purchase     1801900
# 299     2019-10-16 12:04:53+00:00   purchase     5100337
# 376     2019-10-16 12:04:56+00:00   purchase     1306732
# 528     2019-10-16 12:05:05+00:00   purchase     1005105
# 541     2019-10-16 12:05:06+00:00   purchase     1002524
# ...                           ...        ...         ...
# 7073949 2019-10-11 17:54:12+00:00   purchase     1004903
# 7074097 2019-10-11 17:54:18+00:00   purchase     1004249
# 7074484 2019-10-11 17:54:35+00:00   purchase     1005112
# 7074507 2019-10-11 17:54:35+00:00   purchase     1005115
# 7074537 2019-10-11 17:54:36+00:00   purchase     1003306
#
#                   category_code    brand        price    user_id
# 193        electronics.video.tv  samsung   483.459991  551965553
# 299          electronics.clocks    apple   346.730011  557340628
# 376          computers.notebook     asus   360.109985  519274715
# 528      electronics.smartphone    apple  1424.209961  547014958
# 541      electronics.smartphone    apple   537.719971  516606449
# ...                         ...      ...          ...        ...
# 7073949  electronics.smartphone   huawei   111.699997  557936786
# 7074097  electronics.smartphone    apple   766.760010  559250735
# 7074484  electronics.smartphone    apple  1003.849976  512404459
# 7074507  electronics.smartphone    apple  1003.849976  540273893
# 7074537  electronics.smartphone    apple   581.380005  532109668
#
# [116265 rows x 7 columns]

# %%
df_user3['brand'].value_counts(1).head(10).plot.bar(rot=0)
# Out:
# <Axes: >

# %%
df_user3['category_code'].value_counts(1).head(10).plot.barh(rot=0)
# Out:
# <Axes: >

# %% [markdown]
# ### 집단별 고객 클래스 비교

# %%
clu0['RFM_class'].value_counts(1) # 0번 클러스터에는 platinum 고객이 많음
# Out:
# platinum    0.460682
# gold        0.454921
# silver      0.084397
# Name: RFM_class, dtype: float64

# %%
clu1['RFM_class'].value_counts(1) # 1번 클러스터에는 sliver 고객이 많음
# Out:
# silver      0.803323
# gold        0.196569
# platinum    0.000109
# Name: RFM_class, dtype: float64

# %%
clu2['RFM_class'].value_counts(1) # 2번 클러스터에는 platinum 고객이 많음
# Out:
# platinum    0.995396
# gold        0.004518
# silver      0.000086
# Name: RFM_class, dtype: float64

# %%
clu3['RFM_class'].value_counts(1) # 3번 클러스터에는 sliver & gold 고객이 많음
# Out:
# gold        0.507445
# platinum    0.357168
# silver      0.135388
# Name: RFM_class, dtype: float64

# %% [markdown]
# ## 카테고리별 집단 고객 수 비교

# %% [markdown]
# ## 브랜드별 집단 고객 수 비교
